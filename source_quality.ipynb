# %% [markdown]
# ## Getting predatory journals

# %% [markdown]
# We follow Beall's list [here](https://beallslist.net).
#
# Two sections:
# - original list: def red flag
# - Updated list: May be predatory -> yellow flag
#
#
# problem with Beall's list: 82% accuracy, based on the trial of a Science correspondent.

# %%
from bs4 import BeautifulSoup
import requests
import mwparserfromhell
import tldextract

# %%
response = requests.get("https://beallslist.net")
soup = BeautifulSoup(response.content, 'html.parser')
all_list = soup.find_all("ul")
for ele in all_list:
    title = ele.find_previous("h2")
    if title:
        if title.text=="Update":
            update = ele
        elif title.text == "Original list":
            original = ele
        else:
            continue

# %%
original

# %%
from collections import defaultdict
yellow_flags = update.find_all("li")
yellow_flags_dict = defaultdict(dict)
for ele in yellow_flags:
    publication = ele.find("a")
    name, link = publication.text, publication["href"]
    yellow_flags_dict[name] = {"link": link, "acronym": ""}

# %%
len(yellow_flags_dict)
# Out:
# 163

# %%
red_flags = original.find_all("li")
red_flags_dict = defaultdict(dict)
for ele in red_flags:
    publication = ele.find("a")
    if publication:
        name, link = publication.text, publication["href"]
        red_flags_dict[name] = {"link": link, "acronym": ""}
    else:
        # Only 3 journals didn't have a hyperlink
        red_flags_dict[ele.name] = {"link": "", "acronym": ""}

# %%
#one "" different from """"""
test = "American Research Journals"
if test in red_flags_dict:
    print(red_flags_dict[test])
# Out:
# {'link': 'http://www.arjonline.org/', 'acronym': ''}

# %%
# TEST
ext = tldextract.extract('https://web.archive.org/web/20160304232400/http://www.bjournal.co.uk/paper/BJASS_11_1/BJASS_11_01_03.pdf')
ext.domain
# Out:
# 'archive'

# %% [markdown]
# ## Get the type of citation

# %%
pip install tldextract

# %%
pip install bibtexparser

# %%
# TEST
from datetime import datetime 

date = datetime.strptime("2033-jun", '%Y-%b')
print(date)
# Out:
# 2033-06-01 00:00:00

# %%
import bibtexparser
from dateutil import parser
import json

def get_metainfo_doi(doi):
    """Input: doi string
    Output: the journal name and date published of the article. Return None for each value if the can't parsed
    """
    res = requests.get("http://dx.doi.org/"+ doi, headers={"Accept": "application/x-bibtex"})
    res = res.content.decode('utf-8')
    bibtext = bibtexparser.loads(res).entries
    if len(bibtext) >0 :
        journal = bibtext[0]["journal"].strip() if "journal" in bibtext[0] else None
        time_published = ""

        if "year" in bibtext[0]:
            time_published += bibtext[0]["year"]
        if "month" in bibtext[0]:
            time_published += " " + bibtext[0]["month"]
        if "day" in bibtext[0]:
            time_published += " " + bibtext[0]["day"]
        if len(time_published) > 0:
            time_published = parser.parse(time_published)
        else:
            time_published = None

        return journal, time_published
    else:
        return None, None


def get_metainfo_pmc(pmc):
    res = requests.get("https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esummary.fcgi?db=pmc&id="+pmc+"&retmode=json")
    res = res.content.decode("utf-8")
    res = json.loads(res)
    data = res["result"][pmc]
    journal, time_published = None, None
    if "error" in data:
        return None, None
    else:
        journal = data["fulljournalname"].strip()
        time_published = parser.parse(data["pubdate"])
        return journal, time_published


def get_metainfo_pmid(pmid):
    res = requests.get("https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esummary.fcgi?db=pubmed&id="+pmid+"&retmode=json")
    res = res.content.decode("utf-8")
    res = json.loads(res)
    data = res["result"][pmid]
    journal, time_published = None, None
    if "error" in data:
        return None, None
    else:
        journal = data["fulljournalname"].strip()
        time_published = parser.parse(data["pubdate"])
        return journal, time_published

# %%
get_metainfo_doi("10.1038/nrd842")
# get_metainfo_pmc("33829083") #supposed to show error
# get_metainfo_pmc("8008929")
# get_metainfo_pmid("8008929")
# get_metainfo_pmid("25266471")
# Out:
# ('Nature Reviews Drug Discovery', datetime.datetime(2002, 7, 25, 0, 0))

# %%
import requests
import tldextract
from collections import defaultdict

        
def parse_html(page_url):
  """ This function parse metadata of citations from HTML tag.
    Input: wiki_url
    Output: a parsed citation list from HTML. Each citation has format key: value
        key: the text version of all citation
        value: a dictionary with schema 
            {"external_link": str, "type": str, "html_tag": HTMLElement, "publisher": str | None, "date": datetime |None}"""
  
  citation_types = {'web', 'journal', 'book', 'conference', 'news'}
  all_parsed_citations = defaultdict(dict)
  response = requests.get(page_url)
  soup = BeautifulSoup(response.content, 'html.parser')

  # Get all the references
  all_ref = []
  ordered_ref_lst = soup.find_all("ol", {"class": "references"})
  for each in ordered_ref_lst:
    refs = each.find_all("li")
    all_ref += refs

  for ele in all_ref:
    #Check if it has <span class="reference text">
    ref = ele.find("span", {"class":"reference-text"})
    
    source_type = "other" #first default value for source_type

    if ref:
      # TASK: get all essential information from citation tag
      citation_key = ref.get_text()
      hyperlink = ref.find("a", {"class": "external text"})
      external_link = hyperlink["href"] if hyperlink else None

      # TASK: find source type, ie whether it's 'web', 'journal', 'book', 'conference', 'news'
      cite_tag = ref.find("cite") 
      if cite_tag:
        for class_tag in cite_tag["class"]:
          if class_tag in citation_types:
            source_type = class_tag      
            break
          
      # TASK: get publisher (journal name for journal or conference, domain website for webs, 'work' for news)
      #for journal, conference, others look for DOI or PMID or PMC
      if source_type in {'journal', 'conference', 'other'}:
        has_doi = ref.find("a", {"title": "Doi (identifier)"})
        has_pmc = ref.find("a", {"title": "PMC (identifier)"})
        has_pmid = ref.find("a", {"title": "PMID (identifier)"})
        journal, date = None, None
        if has_doi:
          doi = has_doi.find_next("a", {"class": "external text"})
          journal, date = get_metainfo_doi(doi.text)
        elif has_pmc:
          pmc = has_pmc.find_next("a", {"class": "external text"})
          journal, date = get_metainfo_pmc(pmc.text)
        elif has_pmid:
          pmid = has_pmid.find_next("a", {"class": "external text"})
          journal, date = get_metainfo_pmid(pmid.text)         
        
        all_parsed_citations[citation_key] = {"external_link": external_link, "type": source_type, "html_tag": ele, "publisher": journal, "date": date}

      # for news, web, other that hasn't been parsed, publisher is the domain of the website 
      elif source_type in {'news', 'web', 'other'}:
        publisher = tldextract.extract(external_link).domain if external_link else None
        all_parsed_citations[citation_key] = {"external_link": external_link, "type": source_type, "html_tag": ele, "publisher": publisher, "date": None}
        

  return all_parsed_citations

# %%
# test_sol_ac = parse_html("https://en.wikipedia.org/wiki/Solanum_acaule")
test_dem_albania = parse_html("https://en.wikipedia.org/wiki/Democratic_Party_of_Albania")
#test_opth = parse_html("https://en.wikipedia.org/wiki/Optical_coherence_tomography")

# %%
test_dem_albania
# Out:
# defaultdict(dict,
#             {'"European Election Watch Albania". Center for Strategic and International Studies. Retrieved 4 January 2022.': {'external_link': 'https://www.csis.org/programs/european-election-watch/albania',
#               'type': 'web',
#               'html_tag': <li id="cite_note-CSIS-1"><span class="mw-cite-backlink">^ <a href="#cite_ref-CSIS_1-0"><sup><i><b>a</b></i></sup></a> <a href="#cite_ref-CSIS_1-1"><sup><i><b>b</b></i></sup></a> <a href="#cite_ref-CSIS_1-2"><sup><i><b>c</b></i></sup></a> <a href="#cite_ref-CSIS_1-3"><sup><i><b>d</b></i></sup></a></span> <span class="reference-text"><style data-mw-deduplicate="TemplateStyles:r1133582631">.mw-parser-output cite.citation{font-style:inherit;word-wrap:break-word}.mw-parser-output .citation q{quotes:"\"""\"""'""'"}.mw-parser-output .citation:target{background-color:rgba(0,127,255,0.133)}.mw-parser-output .id-lock-free a,.mw-parser-output .citation .cs1-lock-free a{background:url("//upload.wikimedia.org/wikipedia/commons/6/65/Lock-green.svg")right 0.1em center/9px no-repeat}.mw-parser-output .id-lock-limited a,.mw-parser-output .id-lock-registration a,.mw-parser-output .citation .cs1-lock-limited a,.mw-parser-output .citation .cs1-lock-registration a{background:url("//upload.wikimedia.org/wikipedia/commons/d/d6/Lock-gray-alt-2.svg")right 0.1em center/9px no-repeat}.mw-parser-output .id-lock-subscription a,.mw-parser-output .citation .cs1-lock-subscription a{background:url("//upload.wikimedia.org/wikipedia/commons/a/aa/Lock-red-alt-2.svg")right 0.1em center/9px no-repeat}.mw-parser-output .cs1-ws-icon a{background:url("//upload.wikimedia.org/wikipedia/commons/4/4c/Wikisource-logo.svg")right 0.1em center/12px no-repeat}.mw-parser-output .cs1-code{color:inherit;background:inherit;border:none;padding:inherit}.mw-parser-output .cs1-hidden-error{display:none;color:#d33}.mw-parser-output .cs1-visible-error{color:#d33}.mw-parser-output .cs1-maint{display:none;color:#3a3;margin-left:0.3em}.mw-parser-output .cs1-format{font-size:95%}.mw-parser-output .cs1-kern-left{padding-left:0.2em}.mw-parser-output .cs1-kern-right{padding-right:0.2em}.mw-parser-output .citation .mw-selflink{font-weight:inherit}</style><cite class="citation web cs1"><a class="external text" href="https://www.csis.org/programs/european-election-watch/albania" rel="nofollow">"European Election Watch Albania"</a>. <a href="/wiki/Center_for_Strategic_and_International_Studies" title="Center for Strategic and International Studies">Center for Strategic and International Studies</a><span class="reference-accessdate">. Retrieved <span class="nowrap">4 January</span> 2022</span>.</cite><span class="Z3988" title="ctx_ver=Z39.88-2004&amp;rft_val_fmt=info%3Aofi%2Ffmt%3Akev%3Amtx%3Abook&amp;rft.genre=unknown&amp;rft.btitle=European+Election+Watch+Albania&amp;rft.pub=Center+for+Strategic+and+International+Studies&amp;rft_id=https%3A%2F%2Fwww.csis.org%2Fprograms%2Feuropean-election-watch%2Falbania&amp;rfr_id=info%3Asid%2Fen.wikipedia.org%3ADemocratic+Party+of+Albania"></span></span>
#               </li>,
#               'publisher': 'csis',
#               'date': None},
#              '"Berisha Claims He\'s Back in Charge of Albania\'s Democratic Party". 23 May 2022.': {'external_link': 'https://balkaninsight.com/2022/05/23/berisha-claims-hes-back-in-charge-of-albanias-democratic-party/',
#               'type': 'web',
#               'html_tag': <li id="cite_note-2"><span class="mw-cite-backlink"><b><a href="#cite_ref-2">^</a></b></span> <span class="reference-text"><link href="mw-data:TemplateStyles:r1133582631" rel="mw-deduplicated-inline-style"/><cite class="citation web cs1"><a class="external text" href="https://balkaninsight.com/2022/05/23/berisha-claims-hes-back-in-charge-of-albanias-democratic-party/" rel="nofollow">"Berisha Claims He's Back in Charge of Albania's Democratic Party"</a>. 23 May 2022.</cite><span class="Z3988" title="ctx_ver=Z39.88-2004&amp;rft_val_fmt=info%3Aofi%2Ffmt%3Akev%3Amtx%3Abook&amp;rft.genre=unknown&amp;rft.btitle=Berisha+Claims+He%27s+Back+in+Charge+of+Albania%27s+Democratic+Party&amp;rft.date=2022-05-23&amp;rft_id=https%3A%2F%2Fbalkaninsight.com%2F2022%2F05%2F23%2Fberisha-claims-hes-back-in-charge-of-albanias-democratic-party%2F&amp;rfr_id=info%3Asid%2Fen.wikipedia.org%3ADemocratic+Party+of+Albania"></span></span>
#               </li>,
#               'publisher': 'balkaninsight',
#               'date': None},
#              '"Democrat Asks MP to Not Attend Alibeaj\'s Meet on New President".': {'external_link': 'https://albaniandailynews.com/news/democrat-asks-mp-to-not-attend-alibeaj-s-meet-on-new-president',
#               'type': 'web',
#               'html_tag': <li id="cite_note-3"><span class="mw-cite-backlink"><b><a href="#cite_ref-3">^</a></b></span> <span class="reference-text"><link href="mw-data:TemplateStyles:r1133582631" rel="mw-deduplicated-inline-style"/><cite class="citation web cs1"><a class="external text" href="https://albaniandailynews.com/news/democrat-asks-mp-to-not-attend-alibeaj-s-meet-on-new-president" rel="nofollow">"Democrat Asks MP to Not Attend Alibeaj's Meet on New President"</a>.</cite><span class="Z3988" title="ctx_ver=Z39.88-2004&amp;rft_val_fmt=info%3Aofi%2Ffmt%3Akev%3Amtx%3Abook&amp;rft.genre=unknown&amp;rft.btitle=Democrat+Asks+MP+to+Not+Attend+Alibeaj%27s+Meet+on+New+President&amp;rft_id=https%3A%2F%2Falbaniandailynews.com%2Fnews%2Fdemocrat-asks-mp-to-not-attend-alibeaj-s-meet-on-new-president&amp;rfr_id=info%3Asid%2Fen.wikipedia.org%3ADemocratic+Party+of+Albania"></span></span>
#               </li>,
#               'publisher': 'albaniandailynews',
#               'date': None},
#              '"Albanian opposition won\'t elect new leader following chairman\'s resignation". 23 March 2022.': {'external_link': 'https://www.euractiv.com/section/politics/short_news/albanian-opposition-wont-elect-new-leader-following-chairmans-resignation/',
#               'type': 'web',
#               'html_tag': <li id="cite_note-4"><span class="mw-cite-backlink"><b><a href="#cite_ref-4">^</a></b></span> <span class="reference-text"><link href="mw-data:TemplateStyles:r1133582631" rel="mw-deduplicated-inline-style"/><cite class="citation web cs1"><a class="external text" href="https://www.euractiv.com/section/politics/short_news/albanian-opposition-wont-elect-new-leader-following-chairmans-resignation/" rel="nofollow">"Albanian opposition won't elect new leader following chairman's resignation"</a>. 23 March 2022.</cite><span class="Z3988" title="ctx_ver=Z39.88-2004&amp;rft_val_fmt=info%3Aofi%2Ffmt%3Akev%3Amtx%3Abook&amp;rft.genre=unknown&amp;rft.btitle=Albanian+opposition+won%27t+elect+new+leader+following+chairman%27s+resignation&amp;rft.date=2022-03-23&amp;rft_id=https%3A%2F%2Fwww.euractiv.com%2Fsection%2Fpolitics%2Fshort_news%2Falbanian-opposition-wont-elect-new-leader-following-chairmans-resignation%2F&amp;rfr_id=info%3Asid%2Fen.wikipedia.org%3ADemocratic+Party+of+Albania"></span></span>
#               </li>,
#               'publisher': 'euractiv',
#               'date': None},
#              '"Flamur Noka is elected General Secretary of the Democratic Party". politiko.al. Retrieved 29 June 2022.': {'external_link': 'https://politiko.al/english/ditari-i-opozites/flamur-noka-zgjidhet-sekretar-i-pergjithshem-i-pd-i461157',
#               'type': 'web',
#               'html_tag': <li id="cite_note-5"><span class="mw-cite-backlink"><b><a href="#cite_ref-5">^</a></b></span> <span class="reference-text"><link href="mw-data:TemplateStyles:r1133582631" rel="mw-deduplicated-inline-style"/><cite class="citation web cs1"><a class="external text" href="https://politiko.al/english/ditari-i-opozites/flamur-noka-zgjidhet-sekretar-i-pergjithshem-i-pd-i461157" rel="nofollow">"Flamur Noka is elected General Secretary of the Democratic Party"</a>. <i>politiko.al</i><span class="reference-accessdate">. Retrieved <span class="nowrap">29 June</span> 2022</span>.</cite><span class="Z3988" title="ctx_ver=Z39.88-2004&amp;rft_val_fmt=info%3Aofi%2Ffmt%3Akev%3Amtx%3Ajournal&amp;rft.genre=unknown&amp;rft.jtitle=politiko.al&amp;rft.atitle=Flamur+Noka+is+elected+General+Secretary+of+the+Democratic+Party&amp;rft_id=https%3A%2F%2Fpolitiko.al%2Fenglish%2Fditari-i-opozites%2Fflamur-noka-zgjidhet-sekretar-i-pergjithshem-i-pd-i461157&amp;rfr_id=info%3Asid%2Fen.wikipedia.org%3ADemocratic+Party+of+Albania"></span></span>
#               </li>,
#               'publisher': 'politiko',
#               'date': None},
#              'Robert Elsie (2010) Historical Dictionary of Albania, Scarecrow Press, pxliii': {'external_link': None,
#               'type': 'other',
#               'html_tag': <li id="cite_note-6"><span class="mw-cite-backlink"><b><a href="#cite_ref-6">^</a></b></span> <span class="reference-text">Robert Elsie (2010) <i>Historical Dictionary of Albania</i>, Scarecrow Press, pxliii</span>
#               </li>,
#               'publisher': None,
#               'date': None},
#              '"Berisha nga Durrësi: 40 mijë demokratë u ngritën për t\'i rikthyer vlerën partisë, Prokuroria Speciale është bërë e rrezikshme për Ramën". 17 May 2022.': {'external_link': 'https://newsbomb.al/berisha-nga-durresi-40-mije-demokrate-u-ngriten-per-ti-rikthyer-vleren-partise-prokuroria-speciale-eshte-bere-e-rrezikshme-per-ramen/',
#               'type': 'web',
#               'html_tag': <li id="cite_note-7"><span class="mw-cite-backlink"><b><a href="#cite_ref-7">^</a></b></span> <span class="reference-text"><link href="mw-data:TemplateStyles:r1133582631" rel="mw-deduplicated-inline-style"/><cite class="citation web cs1"><a class="external text" href="https://newsbomb.al/berisha-nga-durresi-40-mije-demokrate-u-ngriten-per-ti-rikthyer-vleren-partise-prokuroria-speciale-eshte-bere-e-rrezikshme-per-ramen/" rel="nofollow">"Berisha nga Durrësi: 40 mijë demokratë u ngritën për t'i rikthyer vlerën partisë, Prokuroria Speciale është bërë e rrezikshme për Ramën"</a>. 17 May 2022.</cite><span class="Z3988" title="ctx_ver=Z39.88-2004&amp;rft_val_fmt=info%3Aofi%2Ffmt%3Akev%3Amtx%3Abook&amp;rft.genre=unknown&amp;rft.btitle=Berisha+nga+Durr%C3%ABsi%3A+40+mij%C3%AB+demokrat%C3%AB+u+ngrit%C3%ABn+p%C3%ABr+t%27i+rikthyer+vler%C3%ABn+partis%C3%AB%2C+Prokuroria+Speciale+%C3%ABsht%C3%AB+b%C3%ABr%C3%AB+e+rrezikshme+p%C3%ABr+Ram%C3%ABn&amp;rft.date=2022-05-17&amp;rft_id=https%3A%2F%2Fnewsbomb.al%2Fberisha-nga-durresi-40-mije-demokrate-u-ngriten-per-ti-rikthyer-vleren-partise-prokuroria-speciale-eshte-bere-e-rrezikshme-per-ramen%2F&amp;rfr_id=info%3Asid%2Fen.wikipedia.org%3ADemocratic+Party+of+Albania"></span></span>
#               </li>,
#               'publisher': 'newsbomb',
#               'date': None},
#              'Nordsieck, Wolfram (2017). "Albania". Parties and Elections in Europe.': {'external_link': 'http://www.parties-and-elections.eu/albania.html',
#               'type': 'web',
#               'html_tag': <li id="cite_note-Nordsieck-8"><span class="mw-cite-backlink">^ <a href="#cite_ref-Nordsieck_8-0"><sup><i><b>a</b></i></sup></a> <a href="#cite_ref-Nordsieck_8-1"><sup><i><b>b</b></i></sup></a></span> <span class="reference-text"><link href="mw-data:TemplateStyles:r1133582631" rel="mw-deduplicated-inline-style"/><cite class="citation web cs1" id="CITEREFNordsieck2017">Nordsieck, Wolfram (2017). <a class="external text" href="http://www.parties-and-elections.eu/albania.html" rel="nofollow">"Albania"</a>. <i>Parties and Elections in Europe</i>.</cite><span class="Z3988" title="ctx_ver=Z39.88-2004&amp;rft_val_fmt=info%3Aofi%2Ffmt%3Akev%3Amtx%3Ajournal&amp;rft.genre=unknown&amp;rft.jtitle=Parties+and+Elections+in+Europe&amp;rft.atitle=Albania&amp;rft.date=2017&amp;rft.aulast=Nordsieck&amp;rft.aufirst=Wolfram&amp;rft_id=http%3A%2F%2Fwww.parties-and-elections.eu%2Falbania.html&amp;rfr_id=info%3Asid%2Fen.wikipedia.org%3ADemocratic+Party+of+Albania"></span></span>
#               </li>,
#               'publisher': 'parties-and-elections',
#               'date': None},
#              '"The Albanian Electoral Systems since 1990" (PDF). Albanian Elections Observatory Brief. Hellenic Foundation for European & Foreign Policy (1). 19 April 2013. Retrieved 2 July 2013.': {'external_link': 'http://www.eliamep.gr/wp-content/uploads/2013/04/bn1.pdf',
#               'type': 'journal',
#               'html_tag': <li id="cite_note-aeob13-11"><span class="mw-cite-backlink">^ <a href="#cite_ref-aeob13_11-0"><sup><i><b>a</b></i></sup></a> <a href="#cite_ref-aeob13_11-1"><sup><i><b>b</b></i></sup></a> <a href="#cite_ref-aeob13_11-2"><sup><i><b>c</b></i></sup></a></span> <span class="reference-text"><link href="mw-data:TemplateStyles:r1133582631" rel="mw-deduplicated-inline-style"/><cite class="citation journal cs1"><a class="external text" href="http://www.eliamep.gr/wp-content/uploads/2013/04/bn1.pdf" rel="nofollow">"The Albanian Electoral Systems since 1990"</a> <span class="cs1-format">(PDF)</span>. <i>Albanian Elections Observatory Brief</i>. Hellenic Foundation for European &amp; Foreign Policy (1). 19 April 2013<span class="reference-accessdate">. Retrieved <span class="nowrap">2 July</span> 2013</span>.</cite><span class="Z3988" title="ctx_ver=Z39.88-2004&amp;rft_val_fmt=info%3Aofi%2Ffmt%3Akev%3Amtx%3Ajournal&amp;rft.genre=article&amp;rft.jtitle=Albanian+Elections+Observatory+Brief&amp;rft.atitle=The+Albanian+Electoral+Systems+since+1990&amp;rft.issue=1&amp;rft.date=2013-04-19&amp;rft_id=http%3A%2F%2Fwww.eliamep.gr%2Fwp-content%2Fuploads%2F2013%2F04%2Fbn1.pdf&amp;rfr_id=info%3Asid%2Fen.wikipedia.org%3ADemocratic+Party+of+Albania"></span></span>
#               </li>,
#               'publisher': None,
#               'date': None},
#              '"Parties and Partners". European People\'s Party.': {'external_link': 'https://www.epp.eu/parties-and-partners/',
#               'type': 'web',
#               'html_tag': <li id="cite_note-EPP-12"><span class="mw-cite-backlink"><b><a href="#cite_ref-EPP_12-0">^</a></b></span> <span class="reference-text"><link href="mw-data:TemplateStyles:r1133582631" rel="mw-deduplicated-inline-style"/><cite class="citation web cs1"><a class="external text" href="https://www.epp.eu/parties-and-partners/" rel="nofollow">"Parties and Partners"</a>. European People's Party.</cite><span class="Z3988" title="ctx_ver=Z39.88-2004&amp;rft_val_fmt=info%3Aofi%2Ffmt%3Akev%3Amtx%3Abook&amp;rft.genre=unknown&amp;rft.btitle=Parties+and+Partners&amp;rft.pub=European+People%27s+Party&amp;rft_id=https%3A%2F%2Fwww.epp.eu%2Fparties-and-partners%2F&amp;rfr_id=info%3Asid%2Fen.wikipedia.org%3ADemocratic+Party+of+Albania"></span></span>
#               </li>,
#               'publisher': 'epp',
#               'date': None},
#              'Doder, Dusko (20 January 1991). "At Last, Albanians Feel Winds of Change". The Chicago Tribune. Tirana. Retrieved 5 July 2013.': {'external_link': 'http://articles.chicagotribune.com/1991-01-20/news/9101060446_1_opposition-parties-green-party-democratic-party',
#               'type': 'news',
#               'html_tag': <li id="cite_note-dod20jan-13"><span class="mw-cite-backlink"><b><a href="#cite_ref-dod20jan_13-0">^</a></b></span> <span class="reference-text"><link href="mw-data:TemplateStyles:r1133582631" rel="mw-deduplicated-inline-style"/><cite class="citation news cs1" id="CITEREFDoder1991">Doder, Dusko (20 January 1991). <a class="external text" href="http://articles.chicagotribune.com/1991-01-20/news/9101060446_1_opposition-parties-green-party-democratic-party" rel="nofollow">"At Last, Albanians Feel Winds of Change"</a>. <i>The Chicago Tribune</i>. Tirana<span class="reference-accessdate">. Retrieved <span class="nowrap">5 July</span> 2013</span>.</cite><span class="Z3988" title="ctx_ver=Z39.88-2004&amp;rft_val_fmt=info%3Aofi%2Ffmt%3Akev%3Amtx%3Ajournal&amp;rft.genre=article&amp;rft.jtitle=The+Chicago+Tribune&amp;rft.atitle=At+Last%2C+Albanians+Feel+Winds+of+Change&amp;rft.date=1991-01-20&amp;rft.aulast=Doder&amp;rft.aufirst=Dusko&amp;rft_id=http%3A%2F%2Farticles.chicagotribune.com%2F1991-01-20%2Fnews%2F9101060446_1_opposition-parties-green-party-democratic-party&amp;rfr_id=info%3Asid%2Fen.wikipedia.org%3ADemocratic+Party+of+Albania"></span></span>
#               </li>,
#               'publisher': 'chicagotribune',
#               'date': None},
#              '"The Communist History Of Albania". (http://thebalkanista.com). The Balkanista. 25 February 2018.': {'external_link': 'http://thebalkanista.com/2018/02/25/communist-history-albania/',
#               'type': 'web',
#               'html_tag': <li id="cite_note-14"><span class="mw-cite-backlink"><b><a href="#cite_ref-14">^</a></b></span> <span class="reference-text"><link href="mw-data:TemplateStyles:r1133582631" rel="mw-deduplicated-inline-style"/><cite class="citation web cs1"><a class="external text" href="http://thebalkanista.com/2018/02/25/communist-history-albania/" rel="nofollow">"The Communist History Of Albania"</a>. <i>(<a class="external free" href="http://thebalkanista.com" rel="nofollow">http://thebalkanista.com</a>)</i>. The Balkanista. 25 February 2018.</cite><span class="Z3988" title="ctx_ver=Z39.88-2004&amp;rft_val_fmt=info%3Aofi%2Ffmt%3Akev%3Amtx%3Ajournal&amp;rft.genre=unknown&amp;rft.jtitle=%28http%3A%2F%2Fthebalkanista.com%29&amp;rft.atitle=The+Communist+History+Of+Albania&amp;rft.date=2018-02-25&amp;rft_id=http%3A%2F%2Fthebalkanista.com%2F2018%2F02%2F25%2Fcommunist-history-albania%2F&amp;rfr_id=info%3Asid%2Fen.wikipedia.org%3ADemocratic+Party+of+Albania"></span></span>
#               </li>,
#               'publisher': 'thebalkanista',
#               'date': None},
#              '"Communist-Era Disappearances Still Haunt Albania". (https://balkaninsight.com). Balkan Insight. 15 March 2021.': {'external_link': 'https://balkaninsight.com/2021/03/15/communist-era-disappearances-still-haunt-albania/',
#               'type': 'web',
#               'html_tag': <li id="cite_note-15"><span class="mw-cite-backlink"><b><a href="#cite_ref-15">^</a></b></span> <span class="reference-text"><link href="mw-data:TemplateStyles:r1133582631" rel="mw-deduplicated-inline-style"/><cite class="citation web cs1"><a class="external text" href="https://balkaninsight.com/2021/03/15/communist-era-disappearances-still-haunt-albania/" rel="nofollow">"Communist-Era Disappearances Still Haunt Albania"</a>. <i>(<a class="external free" href="https://balkaninsight.com" rel="nofollow">https://balkaninsight.com</a>)</i>. Balkan Insight. 15 March 2021.</cite><span class="Z3988" title="ctx_ver=Z39.88-2004&amp;rft_val_fmt=info%3Aofi%2Ffmt%3Akev%3Amtx%3Ajournal&amp;rft.genre=unknown&amp;rft.jtitle=%28https%3A%2F%2Fbalkaninsight.com%29&amp;rft.atitle=Communist-Era+Disappearances+Still+Haunt+Albania&amp;rft.date=2021-03-15&amp;rft_id=https%3A%2F%2Fbalkaninsight.com%2F2021%2F03%2F15%2Fcommunist-era-disappearances-still-haunt-albania%2F&amp;rfr_id=info%3Asid%2Fen.wikipedia.org%3ADemocratic+Party+of+Albania"></span></span>
#               </li>,
#               'publisher': 'balkaninsight',
#               'date': None},
#              '"Albania - Collapse of communism | Britannica". www.britannica.com. Retrieved 24 November 2021.': {'external_link': 'https://www.britannica.com/place/Albania/Collapse-of-communism',
#               'type': 'web',
#               'html_tag': <li id="cite_note-16"><span class="mw-cite-backlink"><b><a href="#cite_ref-16">^</a></b></span> <span class="reference-text"><link href="mw-data:TemplateStyles:r1133582631" rel="mw-deduplicated-inline-style"/><cite class="citation web cs1"><a class="external text" href="https://www.britannica.com/place/Albania/Collapse-of-communism" rel="nofollow">"Albania - Collapse of communism | Britannica"</a>. <i>www.britannica.com</i><span class="reference-accessdate">. Retrieved <span class="nowrap">24 November</span> 2021</span>.</cite><span class="Z3988" title="ctx_ver=Z39.88-2004&amp;rft_val_fmt=info%3Aofi%2Ffmt%3Akev%3Amtx%3Ajournal&amp;rft.genre=unknown&amp;rft.jtitle=www.britannica.com&amp;rft.atitle=Albania+-+Collapse+of+communism+%7C+Britannica&amp;rft_id=https%3A%2F%2Fwww.britannica.com%2Fplace%2FAlbania%2FCollapse-of-communism&amp;rfr_id=info%3Asid%2Fen.wikipedia.org%3ADemocratic+Party+of+Albania"></span></span>
#               </li>,
#               'publisher': 'britannica',
#               'date': None},
#              '"Republic of Albania: A Technical Assessment of the Election of the Peoples Assembly, March 9 - April 2, 1992". IFES. 30 April 1992.': {'external_link': 'https://www.ifes.org/publications/republic-albania-technical-assessment-election-peoples-assembly-march-9-april-2-1992',
#               'type': 'web',
#               'html_tag': <li id="cite_note-18"><span class="mw-cite-backlink"><b><a href="#cite_ref-18">^</a></b></span> <span class="reference-text"><link href="mw-data:TemplateStyles:r1133582631" rel="mw-deduplicated-inline-style"/><cite class="citation web cs1"><a class="external text" href="https://www.ifes.org/publications/republic-albania-technical-assessment-election-peoples-assembly-march-9-april-2-1992" rel="nofollow">"Republic of Albania: A Technical Assessment of the Election of the Peoples Assembly, March 9 - April 2, 1992"</a>. IFES. 30 April 1992.</cite><span class="Z3988" title="ctx_ver=Z39.88-2004&amp;rft_val_fmt=info%3Aofi%2Ffmt%3Akev%3Amtx%3Abook&amp;rft.genre=unknown&amp;rft.btitle=Republic+of+Albania%3A+A+Technical+Assessment+of+the+Election+of+the+Peoples+Assembly%2C+March+9+-+April+2%2C+1992&amp;rft.pub=IFES&amp;rft.date=1992-04-30&amp;rft_id=https%3A%2F%2Fwww.ifes.org%2Fpublications%2Frepublic-albania-technical-assessment-election-peoples-assembly-march-9-april-2-1992&amp;rfr_id=info%3Asid%2Fen.wikipedia.org%3ADemocratic+Party+of+Albania"></span></span>
#               </li>,
#               'publisher': 'ifes',
#               'date': None},
#              '"Albania timeline". (http://news.bbc.co.uk). BBC United Kingdom. 24 January 2012.': {'external_link': 'http://news.bbc.co.uk/2/hi/europe/country_profiles/1004984.stm',
#               'type': 'news',
#               'html_tag': <li id="cite_note-19"><span class="mw-cite-backlink"><b><a href="#cite_ref-19">^</a></b></span> <span class="reference-text"><link href="mw-data:TemplateStyles:r1133582631" rel="mw-deduplicated-inline-style"/><cite class="citation news cs1"><a class="external text" href="http://news.bbc.co.uk/2/hi/europe/country_profiles/1004984.stm" rel="nofollow">"Albania timeline"</a>. <i>(<a class="external free" href="http://news.bbc.co.uk" rel="nofollow">http://news.bbc.co.uk</a>)</i>. BBC United Kingdom. 24 January 2012.</cite><span class="Z3988" title="ctx_ver=Z39.88-2004&amp;rft_val_fmt=info%3Aofi%2Ffmt%3Akev%3Amtx%3Ajournal&amp;rft.genre=article&amp;rft.jtitle=%28http%3A%2F%2Fnews.bbc.co.uk%29&amp;rft.atitle=Albania+timeline&amp;rft.date=2012-01-24&amp;rft_id=http%3A%2F%2Fnews.bbc.co.uk%2F2%2Fhi%2Feurope%2Fcountry_profiles%2F1004984.stm&amp;rfr_id=info%3Asid%2Fen.wikipedia.org%3ADemocratic+Party+of+Albania"></span></span>
#               </li>,
#               'publisher': 'bbc',
#               'date': None},
#              '"Albanian Party Hails Ex-Communist Defeat". The New York Times. Reuters. 24 March 1992.': {'external_link': 'https://www.nytimes.com/1992/03/24/world/albanian-party-hails-ex-communist-defeat.html',
#               'type': 'news',
#               'html_tag': <li id="cite_note-20"><span class="mw-cite-backlink"><b><a href="#cite_ref-20">^</a></b></span> <span class="reference-text"><link href="mw-data:TemplateStyles:r1133582631" rel="mw-deduplicated-inline-style"/><cite class="citation news cs1"><a class="external text" href="https://www.nytimes.com/1992/03/24/world/albanian-party-hails-ex-communist-defeat.html" rel="nofollow">"Albanian Party Hails Ex-Communist Defeat"</a>. <i>The New York Times</i>. Reuters. 24 March 1992.</cite><span class="Z3988" title="ctx_ver=Z39.88-2004&amp;rft_val_fmt=info%3Aofi%2Ffmt%3Akev%3Amtx%3Ajournal&amp;rft.genre=article&amp;rft.jtitle=The+New+York+Times&amp;rft.atitle=Albanian+Party+Hails+Ex-Communist+Defeat&amp;rft.date=1992-03-24&amp;rft_id=https%3A%2F%2Fwww.nytimes.com%2F1992%2F03%2F24%2Fworld%2Falbanian-party-hails-ex-communist-defeat.html&amp;rfr_id=info%3Asid%2Fen.wikipedia.org%3ADemocratic+Party+of+Albania"></span></span>
#               </li>,
#               'publisher': 'nytimes',
#               'date': None},
#              '"Albania Table of Contents". (http://countrystudies.us). countrystudies.': {'external_link': 'http://countrystudies.us/albania/63.htm',
#               'type': 'web',
#               'html_tag': <li id="cite_note-21"><span class="mw-cite-backlink"><b><a href="#cite_ref-21">^</a></b></span> <span class="reference-text"><link href="mw-data:TemplateStyles:r1133582631" rel="mw-deduplicated-inline-style"/><cite class="citation web cs1"><a class="external text" href="http://countrystudies.us/albania/63.htm" rel="nofollow">"Albania Table of Contents"</a>. <i>(<a class="external free" href="http://countrystudies.us" rel="nofollow">http://countrystudies.us</a>)</i>. countrystudies.</cite><span class="Z3988" title="ctx_ver=Z39.88-2004&amp;rft_val_fmt=info%3Aofi%2Ffmt%3Akev%3Amtx%3Ajournal&amp;rft.genre=unknown&amp;rft.jtitle=%28http%3A%2F%2Fcountrystudies.us%29&amp;rft.atitle=Albania+Table+of+Contents&amp;rft_id=http%3A%2F%2Fcountrystudies.us%2Falbania%2F63.htm&amp;rfr_id=info%3Asid%2Fen.wikipedia.org%3ADemocratic+Party+of+Albania"></span></span>
#               </li>,
#               'publisher': 'countrystudies',
#               'date': None},
#              '"Albania - GOVERNMENT". Mongabay.com. Retrieved 8 May 2021.': {'external_link': 'https://data.mongabay.com/reference/country_studies/albania/GOVERNMENT.html',
#               'type': 'web',
#               'html_tag': <li id="cite_note-22"><span class="mw-cite-backlink"><b><a href="#cite_ref-22">^</a></b></span> <span class="reference-text"><link href="mw-data:TemplateStyles:r1133582631" rel="mw-deduplicated-inline-style"/><cite class="citation web cs1"><a class="external text" href="https://data.mongabay.com/reference/country_studies/albania/GOVERNMENT.html" rel="nofollow">"Albania - GOVERNMENT"</a>. Mongabay.com<span class="reference-accessdate">. Retrieved <span class="nowrap">8 May</span> 2021</span>.</cite><span class="Z3988" title="ctx_ver=Z39.88-2004&amp;rft_val_fmt=info%3Aofi%2Ffmt%3Akev%3Amtx%3Abook&amp;rft.genre=unknown&amp;rft.btitle=Albania+-+GOVERNMENT&amp;rft.pub=Mongabay.com&amp;rft_id=https%3A%2F%2Fdata.mongabay.com%2Freference%2Fcountry_studies%2Falbania%2FGOVERNMENT.html&amp;rfr_id=info%3Asid%2Fen.wikipedia.org%3ADemocratic+Party+of+Albania"></span></span>
#               </li>,
#               'publisher': 'mongabay',
#               'date': None},
#              '"Parliamentary elections held on May 26th, 1996 in Albania and the political crises they caused". American Research Journals. Retrieved 8 May 2021.': {'external_link': 'https://www.arjonline.org/full-text/parliamentary-elections-held-on-may-26th-1996-in-albania-and-the-political-crises-they-caused/parliamentary-elections-held-on-may-26th-1996-in-albania-and-the-political-crises-they-caused',
#               'type': 'web',
#               'html_tag': <li id="cite_note-23"><span class="mw-cite-backlink"><b><a href="#cite_ref-23">^</a></b></span> <span class="reference-text"><link href="mw-data:TemplateStyles:r1133582631" rel="mw-deduplicated-inline-style"/><cite class="citation web cs1"><a class="external text" href="https://www.arjonline.org/full-text/parliamentary-elections-held-on-may-26th-1996-in-albania-and-the-political-crises-they-caused/parliamentary-elections-held-on-may-26th-1996-in-albania-and-the-political-crises-they-caused" rel="nofollow">"Parliamentary elections held on May 26th, 1996 in Albania and the political crises they caused"</a>. American Research Journals<span class="reference-accessdate">. Retrieved <span class="nowrap">8 May</span> 2021</span>.</cite><span class="Z3988" title="ctx_ver=Z39.88-2004&amp;rft_val_fmt=info%3Aofi%2Ffmt%3Akev%3Amtx%3Abook&amp;rft.genre=unknown&amp;rft.btitle=Parliamentary+elections+held+on+May+26th%2C+1996+in+Albania+and+the+political+crises+they+caused&amp;rft.pub=American+Research+Journals&amp;rft_id=https%3A%2F%2Fwww.arjonline.org%2Ffull-text%2Fparliamentary-elections-held-on-may-26th-1996-in-albania-and-the-political-crises-they-caused%2Fparliamentary-elections-held-on-may-26th-1996-in-albania-and-the-political-crises-they-caused&amp;rfr_id=info%3Asid%2Fen.wikipedia.org%3ADemocratic+Party+of+Albania"></span></span>
#               </li>,
#               'publisher': 'arjonline',
#               'date': None},
#              '"Parliamentary elections held on May 26th, 1996 in Albania and the political crises they caused" (PDF). American Research Journal of History and Culture. 6 (1, 1–9). ISSN\xa02379-2914.': {'external_link': 'https://www.arjonline.org/papers/arjhc/9.pdf',
#               'type': 'journal',
#               'html_tag': <li id="cite_note-arjonline_9-24"><span class="mw-cite-backlink">^ <a href="#cite_ref-arjonline_9_24-0"><sup><i><b>a</b></i></sup></a> <a href="#cite_ref-arjonline_9_24-1"><sup><i><b>b</b></i></sup></a></span> <span class="reference-text"><link href="mw-data:TemplateStyles:r1133582631" rel="mw-deduplicated-inline-style"/><cite class="citation journal cs1"><a class="external text" href="https://www.arjonline.org/papers/arjhc/9.pdf" rel="nofollow">"Parliamentary elections held on May 26th, 1996 in Albania and the political crises they caused"</a> <span class="cs1-format">(PDF)</span>. <i>American Research Journal of History and Culture</i>. <b>6</b> (1, 1–9). <a class="mw-redirect" href="/wiki/ISSN_(identifier)" title="ISSN (identifier)">ISSN</a> <a class="external text" href="https://www.worldcat.org/issn/2379-2914" rel="nofollow">2379-2914</a>.</cite><span class="Z3988" title="ctx_ver=Z39.88-2004&amp;rft_val_fmt=info%3Aofi%2Ffmt%3Akev%3Amtx%3Ajournal&amp;rft.genre=article&amp;rft.jtitle=American+Research+Journal+of+History+and+Culture&amp;rft.atitle=Parliamentary+elections+held+on+May+26th%2C+1996+in+Albania+and+the+political+crises+they+caused&amp;rft.volume=6&amp;rft.issue=1%2C+1%E2%80%939&amp;rft.issn=2379-2914&amp;rft_id=https%3A%2F%2Fwww.arjonline.org%2Fpapers%2Farjhc%2F9.pdf&amp;rfr_id=info%3Asid%2Fen.wikipedia.org%3ADemocratic+Party+of+Albania"></span></span>
#               </li>,
#               'publisher': None,
#               'date': None},
#              '"OBSERVATION OF THE PARLIAMENTARY ELECTIONS HELD IN THE REPUBLIC OF ALBANIA – MAY 26 and JUNE 2, 1996" (PDF). Office for Democratic Institutions and Human Rights. Retrieved 8 May 2021.': {'external_link': 'https://www.osce.org/files/f/documents/8/c/13567.pdf',
#               'type': 'web',
#               'html_tag': <li id="cite_note-25"><span class="mw-cite-backlink"><b><a href="#cite_ref-25">^</a></b></span> <span class="reference-text"><link href="mw-data:TemplateStyles:r1133582631" rel="mw-deduplicated-inline-style"/><cite class="citation web cs1"><a class="external text" href="https://www.osce.org/files/f/documents/8/c/13567.pdf" rel="nofollow">"OBSERVATION OF THE PARLIAMENTARY ELECTIONS HELD IN THE REPUBLIC OF ALBANIA – MAY 26 and JUNE 2, 1996"</a> <span class="cs1-format">(PDF)</span>. Office for Democratic Institutions and Human Rights<span class="reference-accessdate">. Retrieved <span class="nowrap">8 May</span> 2021</span>.</cite><span class="Z3988" title="ctx_ver=Z39.88-2004&amp;rft_val_fmt=info%3Aofi%2Ffmt%3Akev%3Amtx%3Abook&amp;rft.genre=unknown&amp;rft.btitle=OBSERVATION+OF+THE+PARLIAMENTARY+ELECTIONS+HELD+IN+THE+REPUBLIC+OF+ALBANIA+%E2%80%93+MAY+26+and+JUNE+2%2C+1996&amp;rft.pub=Office+for+Democratic+Institutions+and+Human+Rights&amp;rft_id=https%3A%2F%2Fwww.osce.org%2Ffiles%2Ff%2Fdocuments%2F8%2Fc%2F13567.pdf&amp;rfr_id=info%3Asid%2Fen.wikipedia.org%3ADemocratic+Party+of+Albania"></span></span>
#               </li>,
#               'publisher': 'osce',
#               'date': None},
#              '"Parliamentary Chamber: Kuvendi Popullor – ELECTIONS HELD IN 1996". Inter-Parliamentary Union. Retrieved 8 May 2021.': {'external_link': 'http://archive.ipu.org/parline-e/reports/arc/2001_96.htm',
#               'type': 'web',
#               'html_tag': <li id="cite_note-ipu_2001_96-26"><span class="mw-cite-backlink">^ <a href="#cite_ref-ipu_2001_96_26-0"><sup><i><b>a</b></i></sup></a> <a href="#cite_ref-ipu_2001_96_26-1"><sup><i><b>b</b></i></sup></a></span> <span class="reference-text"><link href="mw-data:TemplateStyles:r1133582631" rel="mw-deduplicated-inline-style"/><cite class="citation web cs1"><a class="external text" href="http://archive.ipu.org/parline-e/reports/arc/2001_96.htm" rel="nofollow">"Parliamentary Chamber: Kuvendi Popullor – ELECTIONS HELD IN 1996"</a>. Inter-Parliamentary Union<span class="reference-accessdate">. Retrieved <span class="nowrap">8 May</span> 2021</span>.</cite><span class="Z3988" title="ctx_ver=Z39.88-2004&amp;rft_val_fmt=info%3Aofi%2Ffmt%3Akev%3Amtx%3Abook&amp;rft.genre=unknown&amp;rft.btitle=Parliamentary+Chamber%3A+Kuvendi+Popullor+%E2%80%93+ELECTIONS+HELD+IN+1996&amp;rft.pub=Inter-Parliamentary+Union&amp;rft_id=http%3A%2F%2Farchive.ipu.org%2Fparline-e%2Freports%2Farc%2F2001_96.htm&amp;rfr_id=info%3Asid%2Fen.wikipedia.org%3ADemocratic+Party+of+Albania"></span></span>
#               </li>,
#               'publisher': 'ipu',
#               'date': None},
#              'Hockstader, Lee. "ALBANIAN DREAMS SHATTER IN PYRAMID SCHEMES\' FALL". Washington Post.': {'external_link': 'https://www.washingtonpost.com/archive/politics/1997/02/02/albanian-dreams-shatter-in-pyramid-schemes-fall/d32cf2c6-dd8c-4c52-b61c-50582135a603/',
#               'type': 'news',
#               'html_tag': <li id="cite_note-washingtonpost_1997-02-02-27"><span class="mw-cite-backlink">^ <a href="#cite_ref-washingtonpost_1997-02-02_27-0"><sup><i><b>a</b></i></sup></a> <a href="#cite_ref-washingtonpost_1997-02-02_27-1"><sup><i><b>b</b></i></sup></a></span> <span class="reference-text"><link href="mw-data:TemplateStyles:r1133582631" rel="mw-deduplicated-inline-style"/><cite class="citation news cs1" id="CITEREFHockstader">Hockstader, Lee. <a class="external text" href="https://www.washingtonpost.com/archive/politics/1997/02/02/albanian-dreams-shatter-in-pyramid-schemes-fall/d32cf2c6-dd8c-4c52-b61c-50582135a603/" rel="nofollow">"ALBANIAN DREAMS SHATTER IN PYRAMID SCHEMES' FALL"</a>. <i>Washington Post</i>.</cite><span class="Z3988" title="ctx_ver=Z39.88-2004&amp;rft_val_fmt=info%3Aofi%2Ffmt%3Akev%3Amtx%3Ajournal&amp;rft.genre=article&amp;rft.jtitle=Washington+Post&amp;rft.atitle=ALBANIAN+DREAMS+SHATTER+IN+PYRAMID+SCHEMES%27+FALL&amp;rft.aulast=Hockstader&amp;rft.aufirst=Lee&amp;rft_id=https%3A%2F%2Fwww.washingtonpost.com%2Farchive%2Fpolitics%2F1997%2F02%2F02%2Falbanian-dreams-shatter-in-pyramid-schemes-fall%2Fd32cf2c6-dd8c-4c52-b61c-50582135a603%2F&amp;rfr_id=info%3Asid%2Fen.wikipedia.org%3ADemocratic+Party+of+Albania"></span></span>
#               </li>,
#               'publisher': 'washingtonpost',
#               'date': None},
#              'Jarvis, Christopher. "The Rise and Fall of Albania\'s Pyramid Schemes". imf.org. IMF.': {'external_link': 'https://www.imf.org/external/pubs/ft/fandd/2000/03/jarvis.htm',
#               'type': 'web',
#               'html_tag': <li id="cite_note-28"><span class="mw-cite-backlink"><b><a href="#cite_ref-28">^</a></b></span> <span class="reference-text"><link href="mw-data:TemplateStyles:r1133582631" rel="mw-deduplicated-inline-style"/><cite class="citation web cs1" id="CITEREFJarvis">Jarvis, Christopher. <a class="external text" href="https://www.imf.org/external/pubs/ft/fandd/2000/03/jarvis.htm" rel="nofollow">"The Rise and Fall of Albania's Pyramid Schemes"</a>. <i>imf.org</i>. IMF.</cite><span class="Z3988" title="ctx_ver=Z39.88-2004&amp;rft_val_fmt=info%3Aofi%2Ffmt%3Akev%3Amtx%3Ajournal&amp;rft.genre=unknown&amp;rft.jtitle=imf.org&amp;rft.atitle=The+Rise+and+Fall+of+Albania%27s+Pyramid+Schemes&amp;rft.aulast=Jarvis&amp;rft.aufirst=Christopher&amp;rft_id=https%3A%2F%2Fwww.imf.org%2Fexternal%2Fpubs%2Fft%2Ffandd%2F2000%2F03%2Fjarvis.htm&amp;rfr_id=info%3Asid%2Fen.wikipedia.org%3ADemocratic+Party+of+Albania"></span></span>
#               </li>,
#               'publisher': 'imf',
#               'date': None},
#              'Skarda, Erin (7 March 2012). "Albanian Pyramid Schemes". Time.': {'external_link': 'http://content.time.com/time/specials/packages/article/0,28804,2104982_2104983_2104998,00.html',
#               'type': 'other',
#               'html_tag': <li id="cite_note-29"><span class="mw-cite-backlink"><b><a href="#cite_ref-29">^</a></b></span> <span class="reference-text"><link href="mw-data:TemplateStyles:r1133582631" rel="mw-deduplicated-inline-style"/><cite class="citation magazine cs1" id="CITEREFSkarda2012">Skarda, Erin (7 March 2012). <a class="external text" href="http://content.time.com/time/specials/packages/article/0,28804,2104982_2104983_2104998,00.html" rel="nofollow">"Albanian Pyramid Schemes"</a>. <i>Time</i>.</cite><span class="Z3988" title="ctx_ver=Z39.88-2004&amp;rft_val_fmt=info%3Aofi%2Ffmt%3Akev%3Amtx%3Ajournal&amp;rft.genre=article&amp;rft.jtitle=Time&amp;rft.atitle=Albanian+Pyramid+Schemes&amp;rft.date=2012-03-07&amp;rft.aulast=Skarda&amp;rft.aufirst=Erin&amp;rft_id=http%3A%2F%2Fcontent.time.com%2Ftime%2Fspecials%2Fpackages%2Farticle%2F0%2C28804%2C2104982_2104983_2104998%2C00.html&amp;rfr_id=info%3Asid%2Fen.wikipedia.org%3ADemocratic+Party+of+Albania"></span></span>
#               </li>,
#               'publisher': None,
#               'date': None},
#              '"Albania 1997 Legislative Election". binghamton.edul. The Center on Democratic Performance, Binghamton University.': {'external_link': 'https://www.binghamton.edu/cdp/era/elections/alb97par.html',
#               'type': 'web',
#               'html_tag': <li id="cite_note-30"><span class="mw-cite-backlink"><b><a href="#cite_ref-30">^</a></b></span> <span class="reference-text"><link href="mw-data:TemplateStyles:r1133582631" rel="mw-deduplicated-inline-style"/><cite class="citation web cs1"><a class="external text" href="https://www.binghamton.edu/cdp/era/elections/alb97par.html" rel="nofollow">"Albania 1997 Legislative Election"</a>. <i>binghamton.edul</i>. The Center on Democratic Performance, Binghamton University.</cite><span class="Z3988" title="ctx_ver=Z39.88-2004&amp;rft_val_fmt=info%3Aofi%2Ffmt%3Akev%3Amtx%3Ajournal&amp;rft.genre=unknown&amp;rft.jtitle=binghamton.edul&amp;rft.atitle=Albania+1997+Legislative+Election&amp;rft_id=https%3A%2F%2Fwww.binghamton.edu%2Fcdp%2Fera%2Felections%2Falb97par.html&amp;rfr_id=info%3Asid%2Fen.wikipedia.org%3ADemocratic+Party+of+Albania"></span></span>
#               </li>,
#               'publisher': 'binghamton',
#               'date': None},
#              'Human Rights Watch., International Foundation for Election Systems. "Albania: Voting procedures during the 1997, 2000 and 2001 elections". refworld.org. Canada: Immigration and Refugee Board of Canada. Retrieved 8 May 2021.': {'external_link': 'https://www.refworld.org/docid/3f7d4d4f1c.html',
#               'type': 'web',
#               'html_tag': <li id="cite_note-31"><span class="mw-cite-backlink"><b><a href="#cite_ref-31">^</a></b></span> <span class="reference-text"><link href="mw-data:TemplateStyles:r1133582631" rel="mw-deduplicated-inline-style"/><cite class="citation web cs1" id="CITEREFHuman_Rights_Watch.">Human Rights Watch., International Foundation for Election Systems. <a class="external text" href="https://www.refworld.org/docid/3f7d4d4f1c.html" rel="nofollow">"Albania: Voting procedures during the 1997, 2000 and 2001 elections"</a>. <i>refworld.org</i>. Canada: Immigration and Refugee Board of Canada<span class="reference-accessdate">. Retrieved <span class="nowrap">8 May</span> 2021</span>.</cite><span class="Z3988" title="ctx_ver=Z39.88-2004&amp;rft_val_fmt=info%3Aofi%2Ffmt%3Akev%3Amtx%3Ajournal&amp;rft.genre=unknown&amp;rft.jtitle=refworld.org&amp;rft.atitle=Albania%3A+Voting+procedures+during+the+1997%2C+2000+and+2001+elections&amp;rft.aulast=Human+Rights+Watch.&amp;rft.aufirst=International+Foundation+for+Election+Systems.&amp;rft_id=https%3A%2F%2Fwww.refworld.org%2Fdocid%2F3f7d4d4f1c.html&amp;rfr_id=info%3Asid%2Fen.wikipedia.org%3ADemocratic+Party+of+Albania"></span></span>
#               </li>,
#               'publisher': 'refworld',
#               'date': None},
#              'Topalli, Jozefina. "On the political assassinations, arrests and persecution of the opposition by the neo-communist regime in Albania". hartford-hwp.com. Retrieved 8 May 2021.': {'external_link': 'http://www.hartford-hwp.com/archives/62/354.html',
#               'type': 'web',
#               'html_tag': <li id="cite_note-32"><span class="mw-cite-backlink"><b><a href="#cite_ref-32">^</a></b></span> <span class="reference-text"><link href="mw-data:TemplateStyles:r1133582631" rel="mw-deduplicated-inline-style"/><cite class="citation web cs1" id="CITEREFTopalli">Topalli, Jozefina. <a class="external text" href="http://www.hartford-hwp.com/archives/62/354.html" rel="nofollow">"On the political assassinations, arrests and persecution of the opposition by the neo-communist regime in Albania"</a>. <i>hartford-hwp.com</i><span class="reference-accessdate">. Retrieved <span class="nowrap">8 May</span> 2021</span>.</cite><span class="Z3988" title="ctx_ver=Z39.88-2004&amp;rft_val_fmt=info%3Aofi%2Ffmt%3Akev%3Amtx%3Ajournal&amp;rft.genre=unknown&amp;rft.jtitle=hartford-hwp.com&amp;rft.atitle=On+the+political+assassinations%2C+arrests+and+persecution+of+the+opposition+by+the+neo-communist+regime+in+Albania&amp;rft.aulast=Topalli&amp;rft.aufirst=Jozefina&amp;rft_id=http%3A%2F%2Fwww.hartford-hwp.com%2Farchives%2F62%2F354.html&amp;rfr_id=info%3Asid%2Fen.wikipedia.org%3ADemocratic+Party+of+Albania"></span></span>
#               </li>,
#               'publisher': 'hartford-hwp',
#               'date': None},
#              '"World: Europe Violent protests at Albanian PM\'s office". news.bbc.co.uk. BBC. 13 September 1998.': {'external_link': 'http://news.bbc.co.uk/2/hi/europe/170367.stm',
#               'type': 'web',
#               'html_tag': <li id="cite_note-33"><span class="mw-cite-backlink"><b><a href="#cite_ref-33">^</a></b></span> <span class="reference-text"><link href="mw-data:TemplateStyles:r1133582631" rel="mw-deduplicated-inline-style"/><cite class="citation web cs1"><a class="external text" href="http://news.bbc.co.uk/2/hi/europe/170367.stm" rel="nofollow">"World: Europe Violent protests at Albanian PM's office"</a>. <i>news.bbc.co.uk</i>. BBC. 13 September 1998.</cite><span class="Z3988" title="ctx_ver=Z39.88-2004&amp;rft_val_fmt=info%3Aofi%2Ffmt%3Akev%3Amtx%3Ajournal&amp;rft.genre=unknown&amp;rft.jtitle=news.bbc.co.uk&amp;rft.atitle=World%3A+Europe+Violent+protests+at+Albanian+PM%27s+office&amp;rft.date=1998-09-13&amp;rft_id=http%3A%2F%2Fnews.bbc.co.uk%2F2%2Fhi%2Feurope%2F170367.stm&amp;rfr_id=info%3Asid%2Fen.wikipedia.org%3ADemocratic+Party+of+Albania"></span></span>
#               </li>,
#               'publisher': 'bbc',
#               'date': None},
#              '"Election - June 2001". www.globalsecurity.org/. GlobalSecurity.org.': {'external_link': 'https://www.globalsecurity.org/military/world/europe/al-politics-2001.htm',
#               'type': 'web',
#               'html_tag': <li id="cite_note-34"><span class="mw-cite-backlink"><b><a href="#cite_ref-34">^</a></b></span> <span class="reference-text"><link href="mw-data:TemplateStyles:r1133582631" rel="mw-deduplicated-inline-style"/><cite class="citation web cs1"><a class="external text" href="https://www.globalsecurity.org/military/world/europe/al-politics-2001.htm" rel="nofollow">"Election - June 2001"</a>. <i>www.globalsecurity.org/</i>. GlobalSecurity.org.</cite><span class="Z3988" title="ctx_ver=Z39.88-2004&amp;rft_val_fmt=info%3Aofi%2Ffmt%3Akev%3Amtx%3Ajournal&amp;rft.genre=unknown&amp;rft.jtitle=www.globalsecurity.org%2F&amp;rft.atitle=Election+-+June+2001&amp;rft_id=https%3A%2F%2Fwww.globalsecurity.org%2Fmilitary%2Fworld%2Feurope%2Fal-politics-2001.htm&amp;rfr_id=info%3Asid%2Fen.wikipedia.org%3ADemocratic+Party+of+Albania"></span></span>
#               </li>,
#               'publisher': 'globalsecurity',
#               'date': None},
#              '"REPUBLIC OF ALBANIA PARLIAMENTARY ELECTIONS 24 June – 19 August 2001" (PDF). www.osce.org/. Office for Democratic Institutions and Human Rights.': {'external_link': 'https://www.osce.org/files/f/documents/6/4/13559.pdf',
#               'type': 'web',
#               'html_tag': <li id="cite_note-35"><span class="mw-cite-backlink"><b><a href="#cite_ref-35">^</a></b></span> <span class="reference-text"><link href="mw-data:TemplateStyles:r1133582631" rel="mw-deduplicated-inline-style"/><cite class="citation web cs1"><a class="external text" href="https://www.osce.org/files/f/documents/6/4/13559.pdf" rel="nofollow">"REPUBLIC OF ALBANIA PARLIAMENTARY ELECTIONS 24 June – 19 August 2001"</a> <span class="cs1-format">(PDF)</span>. <i>www.osce.org/</i>. Office for Democratic Institutions and Human Rights.</cite><span class="Z3988" title="ctx_ver=Z39.88-2004&amp;rft_val_fmt=info%3Aofi%2Ffmt%3Akev%3Amtx%3Ajournal&amp;rft.genre=unknown&amp;rft.jtitle=www.osce.org%2F&amp;rft.atitle=REPUBLIC+OF+ALBANIA+PARLIAMENTARY+ELECTIONS+24+June+%E2%80%93+19+August+2001&amp;rft_id=https%3A%2F%2Fwww.osce.org%2Ffiles%2Ff%2Fdocuments%2F6%2F4%2F13559.pdf&amp;rfr_id=info%3Asid%2Fen.wikipedia.org%3ADemocratic+Party+of+Albania"></span></span>
#               </li>,
#               'publisher': 'osce',
#               'date': None},
#              '"The Gerdec explosions trial ends with 19 convictions". country.eiu.com. Retrieved 7 June 2021.': {'external_link': 'http://country.eiu.com/article.aspx?articleid=338994618&Country=Albania&topic=Politics&subtopic=R_6',
#               'type': 'web',
#               'html_tag': <li id="cite_note-36"><span class="mw-cite-backlink"><b><a href="#cite_ref-36">^</a></b></span> <span class="reference-text"><link href="mw-data:TemplateStyles:r1133582631" rel="mw-deduplicated-inline-style"/><cite class="citation web cs1"><a class="external text" href="http://country.eiu.com/article.aspx?articleid=338994618&amp;Country=Albania&amp;topic=Politics&amp;subtopic=R_6" rel="nofollow">"The Gerdec explosions trial ends with 19 convictions"</a>. <i>country.eiu.com</i><span class="reference-accessdate">. Retrieved <span class="nowrap">7 June</span> 2021</span>.</cite><span class="Z3988" title="ctx_ver=Z39.88-2004&amp;rft_val_fmt=info%3Aofi%2Ffmt%3Akev%3Amtx%3Ajournal&amp;rft.genre=unknown&amp;rft.jtitle=country.eiu.com&amp;rft.atitle=The+Gerdec+explosions+trial+ends+with+19+convictions&amp;rft_id=http%3A%2F%2Fcountry.eiu.com%2Farticle.aspx%3Farticleid%3D338994618%26Country%3DAlbania%26topic%3DPolitics%26subtopic%3DR_6&amp;rfr_id=info%3Asid%2Fen.wikipedia.org%3ADemocratic+Party+of+Albania"></span></span>
#               </li>,
#               'publisher': 'eiu',
#               'date': None},
#              '"United States Concludes Clean Up Effort at Albanian Explosion Site". U.S. Department of State. Retrieved 7 June 2021.': {'external_link': 'https://2009-2017.state.gov/r/pa/prs/ps/2012/12/202271.htm',
#               'type': 'web',
# ...
#               </li>,
#               'publisher': 'sot',
#               'date': None},
#              '"Alibeaj gathers himself, Berisha: He has only the right that Rama gives him. Immigrant vote warning". politiko.al. Retrieved 21 June 2022.': {'external_link': 'https://politiko.al/english/ditari-i-opozites/alibeaj-mbledh-te-vetet-berisha-ka-vetem-tagrin-qe-i-jep-rama--i460590',
#               'type': 'web',
#               'html_tag': <li id="cite_note-58"><span class="mw-cite-backlink"><b><a href="#cite_ref-58">^</a></b></span> <span class="reference-text"><link href="mw-data:TemplateStyles:r1133582631" rel="mw-deduplicated-inline-style"/><cite class="citation web cs1"><a class="external text" href="https://politiko.al/english/ditari-i-opozites/alibeaj-mbledh-te-vetet-berisha-ka-vetem-tagrin-qe-i-jep-rama--i460590" rel="nofollow">"Alibeaj gathers himself, Berisha: He has only the right that Rama gives him. Immigrant vote warning"</a>. <i>politiko.al</i><span class="reference-accessdate">. Retrieved <span class="nowrap">21 June</span> 2022</span>.</cite><span class="Z3988" title="ctx_ver=Z39.88-2004&amp;rft_val_fmt=info%3Aofi%2Ffmt%3Akev%3Amtx%3Ajournal&amp;rft.genre=unknown&amp;rft.jtitle=politiko.al&amp;rft.atitle=Alibeaj+gathers+himself%2C+Berisha%3A+He+has+only+the+right+that+Rama+gives+him.+Immigrant+vote+warning&amp;rft_id=https%3A%2F%2Fpolitiko.al%2Fenglish%2Fditari-i-opozites%2Falibeaj-mbledh-te-vetet-berisha-ka-vetem-tagrin-qe-i-jep-rama--i460590&amp;rfr_id=info%3Asid%2Fen.wikipedia.org%3ADemocratic+Party+of+Albania"></span></span>
#               </li>,
#               'publisher': 'politiko',
#               'date': None},
#              '"Belind Këlliçi shuan zërat se pas Evi Kokalarit qëndron Berisha: Shpifjet i përdori i pari Erion Veliaj!". Lapsi.al (in Albanian). 17 June 2022. Retrieved 22 June 2022.': {'external_link': 'https://lapsi.al/2022/06/17/belind-kellici-shuan-zerat-se-pas-evi-kokalarit-qendron-berisha-shpifjet-i-perdori-i-pari-erion-veliaj/',
#               'type': 'web',
#               'html_tag': <li id="cite_note-59"><span class="mw-cite-backlink"><b><a href="#cite_ref-59">^</a></b></span> <span class="reference-text"><link href="mw-data:TemplateStyles:r1133582631" rel="mw-deduplicated-inline-style"/><cite class="citation web cs1 cs1-prop-foreign-lang-source"><a class="external text" href="https://lapsi.al/2022/06/17/belind-kellici-shuan-zerat-se-pas-evi-kokalarit-qendron-berisha-shpifjet-i-perdori-i-pari-erion-veliaj/" rel="nofollow">"Belind Këlliçi shuan zërat se pas Evi Kokalarit qëndron Berisha: Shpifjet i përdori i pari Erion Veliaj!"</a>. <i>Lapsi.al</i> (in Albanian). 17 June 2022<span class="reference-accessdate">. Retrieved <span class="nowrap">22 June</span> 2022</span>.</cite><span class="Z3988" title="ctx_ver=Z39.88-2004&amp;rft_val_fmt=info%3Aofi%2Ffmt%3Akev%3Amtx%3Ajournal&amp;rft.genre=unknown&amp;rft.jtitle=Lapsi.al&amp;rft.atitle=Belind+K%C3%ABlli%C3%A7i+shuan+z%C3%ABrat+se+pas+Evi+Kokalarit+q%C3%ABndron+Berisha%3A+Shpifjet+i+p%C3%ABrdori+i+pari+Erion+Veliaj%21&amp;rft.date=2022-06-17&amp;rft_id=https%3A%2F%2Flapsi.al%2F2022%2F06%2F17%2Fbelind-kellici-shuan-zerat-se-pas-evi-kokalarit-qendron-berisha-shpifjet-i-perdori-i-pari-erion-veliaj%2F&amp;rfr_id=info%3Asid%2Fen.wikipedia.org%3ADemocratic+Party+of+Albania"></span></span>
#               </li>,
#               'publisher': 'lapsi',
#               'date': None},
#              '"Clashes between Democrats / Belind Këlliçi sued for defamation, comes the immediate reaction of Evi Kokalari". sot.com.al. Retrieved 22 June 2022.': {'external_link': 'https://sot.com.al/english/politike/plas-mes-demokrateve-belind-kellici-e-paditi-per-shpifje-vjen-reagimi-i-i520521',
#               'type': 'web',
#               'html_tag': <li id="cite_note-60"><span class="mw-cite-backlink"><b><a href="#cite_ref-60">^</a></b></span> <span class="reference-text"><link href="mw-data:TemplateStyles:r1133582631" rel="mw-deduplicated-inline-style"/><cite class="citation web cs1"><a class="external text" href="https://sot.com.al/english/politike/plas-mes-demokrateve-belind-kellici-e-paditi-per-shpifje-vjen-reagimi-i-i520521" rel="nofollow">"Clashes between Democrats / Belind Këlliçi sued for defamation, comes the immediate reaction of Evi Kokalari"</a>. <i>sot.com.al</i><span class="reference-accessdate">. Retrieved <span class="nowrap">22 June</span> 2022</span>.</cite><span class="Z3988" title="ctx_ver=Z39.88-2004&amp;rft_val_fmt=info%3Aofi%2Ffmt%3Akev%3Amtx%3Ajournal&amp;rft.genre=unknown&amp;rft.jtitle=sot.com.al&amp;rft.atitle=Clashes+between+Democrats+%2F+Belind+K%C3%ABlli%C3%A7i+sued+for+defamation%2C+comes+the+immediate+reaction+of+Evi+Kokalari&amp;rft_id=https%3A%2F%2Fsot.com.al%2Fenglish%2Fpolitike%2Fplas-mes-demokrateve-belind-kellici-e-paditi-per-shpifje-vjen-reagimi-i-i520521&amp;rfr_id=info%3Asid%2Fen.wikipedia.org%3ADemocratic+Party+of+Albania"></span></span>
#               </li>,
#               'publisher': 'sot',
#               'date': None},
#              '"Thousands of Albanians Participate in Opposition-Led Protest against Government". Exit - Explaining Albania. 8 July 2022. Retrieved 8 July 2022.': {'external_link': 'https://exit.al/en/2022/07/08/thousands-of-albanians-participate-in-opposition-led-protest-against-government/',
#               'type': 'web',
#               'html_tag': <li id="cite_note-61"><span class="mw-cite-backlink"><b><a href="#cite_ref-61">^</a></b></span> <span class="reference-text"><link href="mw-data:TemplateStyles:r1133582631" rel="mw-deduplicated-inline-style"/><cite class="citation web cs1"><a class="external text" href="https://exit.al/en/2022/07/08/thousands-of-albanians-participate-in-opposition-led-protest-against-government/" rel="nofollow">"Thousands of Albanians Participate in Opposition-Led Protest against Government"</a>. <i>Exit - Explaining Albania</i>. 8 July 2022<span class="reference-accessdate">. Retrieved <span class="nowrap">8 July</span> 2022</span>.</cite><span class="Z3988" title="ctx_ver=Z39.88-2004&amp;rft_val_fmt=info%3Aofi%2Ffmt%3Akev%3Amtx%3Ajournal&amp;rft.genre=unknown&amp;rft.jtitle=Exit+-+Explaining+Albania&amp;rft.atitle=Thousands+of+Albanians+Participate+in+Opposition-Led+Protest+against+Government&amp;rft.date=2022-07-08&amp;rft_id=https%3A%2F%2Fexit.al%2Fen%2F2022%2F07%2F08%2Fthousands-of-albanians-participate-in-opposition-led-protest-against-government%2F&amp;rfr_id=info%3Asid%2Fen.wikipedia.org%3ADemocratic+Party+of+Albania"></span></span>
#               </li>,
#               'publisher': 'exit',
#               'date': None},
#              '"Anti-government protests held in Albania". www.aa.com.tr. Retrieved 8 July 2022.': {'external_link': 'https://www.aa.com.tr/en/world/anti-government-protests-held-in-albania/2632870',
#               'type': 'web',
#               'html_tag': <li id="cite_note-62"><span class="mw-cite-backlink"><b><a href="#cite_ref-62">^</a></b></span> <span class="reference-text"><link href="mw-data:TemplateStyles:r1133582631" rel="mw-deduplicated-inline-style"/><cite class="citation web cs1"><a class="external text" href="https://www.aa.com.tr/en/world/anti-government-protests-held-in-albania/2632870" rel="nofollow">"Anti-government protests held in Albania"</a>. <i>www.aa.com.tr</i><span class="reference-accessdate">. Retrieved <span class="nowrap">8 July</span> 2022</span>.</cite><span class="Z3988" title="ctx_ver=Z39.88-2004&amp;rft_val_fmt=info%3Aofi%2Ffmt%3Akev%3Amtx%3Ajournal&amp;rft.genre=unknown&amp;rft.jtitle=www.aa.com.tr&amp;rft.atitle=Anti-government+protests+held+in+Albania&amp;rft_id=https%3A%2F%2Fwww.aa.com.tr%2Fen%2Fworld%2Fanti-government-protests-held-in-albania%2F2632870&amp;rfr_id=info%3Asid%2Fen.wikipedia.org%3ADemocratic+Party+of+Albania"></span></span>
#               </li>,
#               'publisher': 'aa',
#               'date': None},
#              '"Tirana, capital city of Albania". www.visitcapitalcity.com. www.visitcapitalcity.com. 8 March 2020.': {'external_link': 'https://www.visitcapitalcity.com/europe/tirana-albania/',
#               'type': 'web',
#               'html_tag': <li id="cite_note-63"><span class="mw-cite-backlink"><b><a href="#cite_ref-63">^</a></b></span> <span class="reference-text"><link href="mw-data:TemplateStyles:r1133582631" rel="mw-deduplicated-inline-style"/><cite class="citation web cs1"><a class="external text" href="https://www.visitcapitalcity.com/europe/tirana-albania/" rel="nofollow">"Tirana, capital city of Albania"</a>. <i>www.visitcapitalcity.com</i>. www.visitcapitalcity.com. 8 March 2020.</cite><span class="Z3988" title="ctx_ver=Z39.88-2004&amp;rft_val_fmt=info%3Aofi%2Ffmt%3Akev%3Amtx%3Ajournal&amp;rft.genre=unknown&amp;rft.jtitle=www.visitcapitalcity.com&amp;rft.atitle=Tirana%2C+capital+city+of+Albania&amp;rft.date=2020-03-08&amp;rft_id=https%3A%2F%2Fwww.visitcapitalcity.com%2Feurope%2Ftirana-albania%2F&amp;rfr_id=info%3Asid%2Fen.wikipedia.org%3ADemocratic+Party+of+Albania"></span></span>
#               </li>,
#               'publisher': 'visitcapitalcity',
#               'date': None},
#              'Bakke, Elisabeth (18 February 2010), "Central and East European party systems since 1989", Central and Southeast European Politics since 1989, Cambridge University Press, pp.\xa064–90, retrieved 30 January 2023': {'external_link': 'https://dx.doi.org/10.1017/cbo9780511803185.008',
#               'type': 'other',
#               'html_tag': <li id="cite_note-64"><span class="mw-cite-backlink"><b><a href="#cite_ref-64">^</a></b></span> <span class="reference-text"><link href="mw-data:TemplateStyles:r1133582631" rel="mw-deduplicated-inline-style"/><cite class="citation cs2" id="CITEREFBakke2010">Bakke, Elisabeth (18 February 2010), <a class="external text" href="https://dx.doi.org/10.1017/cbo9780511803185.008" rel="nofollow">"Central and East European party systems since 1989"</a>, <i>Central and Southeast European Politics since 1989</i>, Cambridge University Press, pp. 64–90<span class="reference-accessdate">, retrieved <span class="nowrap">30 January</span> 2023</span></cite><span class="Z3988" title="ctx_ver=Z39.88-2004&amp;rft_val_fmt=info%3Aofi%2Ffmt%3Akev%3Amtx%3Ajournal&amp;rft.genre=article&amp;rft.jtitle=Central+and+Southeast+European+Politics+since+1989&amp;rft.atitle=Central+and+East+European+party+systems+since+1989&amp;rft.pages=64-90&amp;rft.date=2010-02-18&amp;rft.aulast=Bakke&amp;rft.aufirst=Elisabeth&amp;rft_id=http%3A%2F%2Fdx.doi.org%2F10.1017%2Fcbo9780511803185.008&amp;rfr_id=info%3Asid%2Fen.wikipedia.org%3ADemocratic+Party+of+Albania"></span></span>
#               </li>,
#               'publisher': None,
#               'date': None},
#              '"Berisha Reacts after Alibeaj\'s Withdrawal from Appeal". ALBANIA DAILY NEWS. Retrieved 23 January 2023.': {'external_link': 'https://albaniandailynews.com/news/berisha-reacts-after-alibeaj-s-withdrawal-from-appeal',
#               'type': 'web',
#               'html_tag': <li id="cite_note-66"><span class="mw-cite-backlink"><b><a href="#cite_ref-66">^</a></b></span> <span class="reference-text"><link href="mw-data:TemplateStyles:r1133582631" rel="mw-deduplicated-inline-style"/><cite class="citation web cs1"><a class="external text" href="https://albaniandailynews.com/news/berisha-reacts-after-alibeaj-s-withdrawal-from-appeal" rel="nofollow">"Berisha Reacts after Alibeaj's Withdrawal from Appeal"</a>. <i>ALBANIA DAILY NEWS</i><span class="reference-accessdate">. Retrieved <span class="nowrap">23 January</span> 2023</span>.</cite><span class="Z3988" title="ctx_ver=Z39.88-2004&amp;rft_val_fmt=info%3Aofi%2Ffmt%3Akev%3Amtx%3Ajournal&amp;rft.genre=unknown&amp;rft.jtitle=ALBANIA+DAILY+NEWS&amp;rft.atitle=Berisha+Reacts+after+Alibeaj%27s+Withdrawal+from+Appeal&amp;rft_id=https%3A%2F%2Falbaniandailynews.com%2Fnews%2Fberisha-reacts-after-alibeaj-s-withdrawal-from-appeal&amp;rfr_id=info%3Asid%2Fen.wikipedia.org%3ADemocratic+Party+of+Albania"></span></span>
#               </li>,
#               'publisher': 'albaniandailynews',
#               'date': None},
#              '"Përjashtimi i deputetëve/ Alibeaj në realitet tjetër: Unë jam drejtuesi i PD". Lapsi.al (in Albanian). 12 January 2023. Retrieved 23 January 2023.': {'external_link': 'https://lapsi.al/2023/01/12/perjashtimi-i-deputeteve-delir-alibeaj-ne-realitet-tjeter-une-perfaqesoj-demokratet/',
#               'type': 'web',
#               'html_tag': <li id="cite_note-67"><span class="mw-cite-backlink"><b><a href="#cite_ref-67">^</a></b></span> <span class="reference-text"><link href="mw-data:TemplateStyles:r1133582631" rel="mw-deduplicated-inline-style"/><cite class="citation web cs1 cs1-prop-foreign-lang-source"><a class="external text" href="https://lapsi.al/2023/01/12/perjashtimi-i-deputeteve-delir-alibeaj-ne-realitet-tjeter-une-perfaqesoj-demokratet/" rel="nofollow">"Përjashtimi i deputetëve/ Alibeaj në realitet tjetër: Unë jam drejtuesi i PD"</a>. <i>Lapsi.al</i> (in Albanian). 12 January 2023<span class="reference-accessdate">. Retrieved <span class="nowrap">23 January</span> 2023</span>.</cite><span class="Z3988" title="ctx_ver=Z39.88-2004&amp;rft_val_fmt=info%3Aofi%2Ffmt%3Akev%3Amtx%3Ajournal&amp;rft.genre=unknown&amp;rft.jtitle=Lapsi.al&amp;rft.atitle=P%C3%ABrjashtimi+i+deputet%C3%ABve%2F+Alibeaj+n%C3%AB+realitet+tjet%C3%ABr%3A+Un%C3%AB+jam+drejtuesi+i+PD&amp;rft.date=2023-01-12&amp;rft_id=https%3A%2F%2Flapsi.al%2F2023%2F01%2F12%2Fperjashtimi-i-deputeteve-delir-alibeaj-ne-realitet-tjeter-une-perfaqesoj-demokratet%2F&amp;rfr_id=info%3Asid%2Fen.wikipedia.org%3ADemocratic+Party+of+Albania"></span></span>
#               </li>,
#               'publisher': 'lapsi',
#               'date': None},
#              '""Lufta" e numrave në PD/ Kush është me Berishën e kush me Alibeajn-Emrat". CNA. 11 January 2023. Retrieved 23 January 2023.': {'external_link': 'https://www.cna.al/politike/lufta-e-numrave-ne-pd-kush-eshte-me-berishen-e-kush-me-alibeajt-emrat-i345678',
#               'type': 'web',
#               'html_tag': <li id="cite_note-68"><span class="mw-cite-backlink"><b><a href="#cite_ref-68">^</a></b></span> <span class="reference-text"><link href="mw-data:TemplateStyles:r1133582631" rel="mw-deduplicated-inline-style"/><cite class="citation web cs1"><a class="external text" href="https://www.cna.al/politike/lufta-e-numrave-ne-pd-kush-eshte-me-berishen-e-kush-me-alibeajt-emrat-i345678" rel="nofollow">"<span class="cs1-kern-left"></span>"Lufta" e numrave në PD/ Kush është me Berishën e kush me Alibeajn-Emrat"</a>. <i>CNA</i>. 11 January 2023<span class="reference-accessdate">. Retrieved <span class="nowrap">23 January</span> 2023</span>.</cite><span class="Z3988" title="ctx_ver=Z39.88-2004&amp;rft_val_fmt=info%3Aofi%2Ffmt%3Akev%3Amtx%3Ajournal&amp;rft.genre=unknown&amp;rft.jtitle=CNA&amp;rft.atitle=%22Lufta%22+e+numrave+n%C3%AB+PD%2F+Kush+%C3%ABsht%C3%AB+me+Berish%C3%ABn+e+kush+me+Alibeajn-Emrat&amp;rft.date=2023-01-11&amp;rft_id=https%3A%2F%2Fwww.cna.al%2Fpolitike%2Flufta-e-numrave-ne-pd-kush-eshte-me-berishen-e-kush-me-alibeajt-emrat-i345678&amp;rfr_id=info%3Asid%2Fen.wikipedia.org%3ADemocratic+Party+of+Albania"></span></span>
#               </li>,
#               'publisher': 'cna',
#               'date': None}})

# %% [markdown]
# ## Match with WikiText

# %%
pip install mwparserfromhell

# %%
import re
from difflib import SequenceMatcher
from dateutil import parser

def parse_match_wikitext(wiki_url):
    """
    This function parse wikitext version of the citations, match it with the HTML version, 
    and extract more information, such as publisher and date that weren't extracted on the HTML.
    Input: wiki_url
    Output: a fully parsed citation list. Each citation has format key: value
        key: the text version of all citation
        value: a dictionary with schema 
            {"external_link": str, "type": str, "html_tag": HTMLElement, "publisher": str | None, "date": datetime |None}
    """
    parsed_citation = parse_html(wiki_url)
    print("ALL citation", len(parsed_citation))
    wiki_page = wiki_url.split("wiki/")[1]
    url = "https://en.wikipedia.org/w/index.php?title=" + wiki_page +"&action=raw"
    response = requests.get(url)
    text = response.text
    wikicode = mwparserfromhell.parse(text)
    
    all_found = 0

    # Create a copy of not fully parsed citation, ie one that lacks publisher or date param
    not_fully_parsed = defaultdict(dict)
    for key, val in parsed_citation.items():
        if not val["publisher"] or not val["date"]:
            not_fully_parsed[key] = val

    for tpl in wikicode.filter_templates(matches="{{cite"):
        #tpl is template, for a template in wikitext
        found_match = None
        
        # Match on external link:
        if tpl.has_param("url"):
            external_url = tpl.get("url").split("=")[1]
            for key, val in not_fully_parsed.items():
                if val["external_link"]:
                    if val["external_link"].strip() == external_url.strip():
                        found_match = key
                        all_found += 1
                        break
        # if not found match by URL, find by title
        if not found_match:
            if tpl.has_param("title"):
                #Get the title of citation in without formatting text
                title = tpl.get("title").split("=")[1] 
                title = re.sub('[^A-Za-z0-9 ]+', '', title) #filter out extra formatting
                for key in not_fully_parsed.keys():
                    if title in key:
                        found_match = key
                        all_found += 1
                        break
        
        if found_match:
            # Fetch publisher/ journal name from wikitext
            if not parsed_citation[found_match]["publisher"]:
                publisher = None
                if tpl.has_param("journal"): #for journal name
                    publisher = tpl.get("journal").split("=")[1] 
                elif tpl.has_param("publishder"): #for website or book publisher
                    publisher = tpl.get("publisher").split("=")[1]
                elif tpl.has_param("work"): #for news/ magazine name
                    publisher = tpl.get("work").split("=")[1]
                
                if publisher:
                    publisher = re.sub('[^A-Za-z0-9 ]+', '', publisher)
                parsed_citation[found_match]["publisher"] = publisher

            # Fetch publication date from wikitext
            if not parsed_citation[found_match]["date"]:
                date = None
                if tpl.has_param("date"):
                    date = tpl.get("date").split("=")[1]
                    if len(date) >= 4: #at least 4 digits for year, or yy-mm format
                        date = parser.parse(date)
                parsed_citation[found_match]["date"] = date
            

    print("TOTAL MATCH: ", all_found)
    return parsed_citation
        

def check_source_quality(wiki_url):
    parsed = parse_match_wikitext(wiki_url)
    red_flag_list = []
    yellow_flag_list = []

    for citation in parsed:
        # Check for journals/ conference/ other
        if citation["type"] in {"journal", "conference", "other"}:
            # Check on the domain of external link
            if citation["external_link"]:
                domain = tldextract.extract(citation["external_link"]).domain
                if domain 
            # Check on the journal name
        



        #TODO: Find the journal name -> check if it's in red or yellow list
            # TODO: split it to a different support function
        # if tpl.has("journal"):
        #     journal = tpl.get("journal").split("=")[1]
        #     if journal == "American Research Journals":
        #         print(tpl)
        #     if journal in red_flags_dict.keys():
        #         print("RED FLAG: ", journal)
        #     if journal in yellow_flags_dict.keys():
        #         print("YELLO FLAG: ", journal)
parsed = parse_match_wikitext("https://en.wikipedia.org/wiki/Optical_coherence_tomography")
# Out:
# ALL citation 102
# TOTAL MATCH:  14

# %%
# TEST
parser.parse("23 March 2022 ")
# Out:
# datetime.datetime(2022, 3, 23, 0, 0)

# %%
"Cyst Nematode and its Impacts on Soybean and Potato: A Review" in """Rehman, Fazal UR (30 April 2021). "Cyst Nematode and its Impacts on Soybean and Potato: A Review". Acta Scientific Biotechnology. 2 (2): 17–22. Retrieved 13 November 2021."""
# Out:
# True

# %%
a = mwparserfromhell.parse("{{cite |last1=Rehman |first1=Fazal UR |date=30 April 2021 |title=Cyst Nematode and its Impacts on Soybean and Potato: A Review |url=https://www.researchgate.net/publication/351345007 |journal=Acta Scientific Biotechnology |volume=2 |issue=2 |pages=17–22 |doi= |access-date=13 November 2021 }}").filter(matches="{{cite")
for ele in a:
    pass
    # if ele.has("title"):
    #     title = ele.get("title").split("=")[1]
    #     print(title)

# %%
def evaluate_citation(wikiUrl):
    """Input: English Wikipedia URL 
    Output:
    - how many citations each type has
        - red-flag articles/ news/ website
        - yellow-flag articles/  news/ sites
        - green-flag artciles/ news/ sites
    - Summary stats about publication/ access date
    - summary dataviz on type distribution: pie chart
    """
    pass

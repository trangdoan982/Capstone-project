# %% [markdown]
# ### Introduction
# This notebook fetches information from Beall's list to find the URL and name of predatory journals, which will be tagged red and yellow flags for scholarly sources

# %%
# Import all the models
from bs4 import BeautifulSoup
import requests
import mwparserfromhell
import tldextract

# %%
# scrape the Beall's List website for lists of journals. Original list contains red flag journals, while Updated list contains green flag journals
response = requests.get("https://beallslist.net")
soup = BeautifulSoup(response.content, 'html.parser')
all_list = soup.find_all("ul")
for ele in all_list:
    title = ele.find_previous("h2")
    if title:
        if title.text=="Update":
            update = ele
        elif title.text == "Original list":
            original = ele
        else:
            continue

# %%
# Create yellow_flags_dict, which has the schema key:value = journal_name: journal_link
from collections import defaultdict
yellow_flags = update.find_all("li")
yellow_flags_dict = defaultdict(dict)
for ele in yellow_flags:
    publication = ele.find("a")
    name, link = publication.text, publication["href"]
    yellow_flags_dict[name] = link

# %%
# Create red_flags_dict, which has the schema key:value = journal_name: journal_link

red_flags = original.find_all("li")
red_flags_dict = defaultdict(dict)
for ele in red_flags:
    publication = ele.find("a")
    link = ""
    if publication:
        name, link = publication.text, publication["href"]
        red_flags_dict[name] = link

# %%
#reverse the yellow_flag_dict and red_flags_dict to create dictionaries whose schema is key:value = domain of link : journal name
red_flags_reverse = defaultdict(list)
yellow_flags_reverse = defaultdict(list)
for key, val in red_flags_dict.items():
    val_domain = tldextract.extract(val).domain
    red_flags_reverse[val_domain].append(key)

for key, val in yellow_flags_dict.items():
    val_domain = tldextract.extract(val).domain
    yellow_flags_reverse[val_domain].append(key)

# %% [markdown]
# ### Fetch green-flag journals
#
# Fetch journals enlisted on DOAJ, which is more likely to have ethical practices for open sourced papers.

# %%
import pandas as pd

doaj = pd.read_csv("doaj.csv")
doaj
# Out:
#                                            Journal title  \
# 0               Anais da Academia Brasileira de Ciências
# 1                                                   ACME
# 2                               Acta Biochimica Polonica
# 3                             Acta Dermato-Venereologica
# 4                              Acta Médica Costarricense
# ...                                                  ...
# 19153                                        Football(s)
# 19154  International Journal of Home Economics, Hospi...
# 19155                                           Papireto
# 19156    Advances in Civil and Architectural Engineering
# 19157                         Science of Tsunami Hazards
#
#                                              Journal URL  \
# 0      http://www.scielo.br/scielo.php?script=sci_ser...
# 1                 http://riviste.unimi.it/index.php/ACME
# 2               https://ojs.ptbioch.edu.pl/index.php/abp
# 3                https://medicaljournalssweden.se/actadv
# 4      http://actamedica.medicos.cr/index.php/Acta_Me...
# ...                                                  ...
# 19153            https://preo.u-bourgogne.fr/football-s/
# 19154                             https://www.ijhhr.org/
# 19155            https://papireto.accademiadipalermo.it/
# 19156     https://hrcak.srce.hr/ojs/index.php/acae/index
# 19157                         http://tsunamisociety.org/
#
#                                              URL in DOAJ  \
# 0      https://doaj.org/toc/ed09859a464f4461b1af34279...
# 1      https://doaj.org/toc/b1ca04ba56194f29a362b3eef...
# 2      https://doaj.org/toc/eea321d7f4c34a59be8fd1203...
# 3      https://doaj.org/toc/ffde9666ab1d46f1a8c688ce6...
# 4      https://doaj.org/toc/a5919aee5ad2413a89cf32df0...
# ...                                                  ...
# 19153  https://doaj.org/toc/ea91a02a465e4dbf8386b899a...
# 19154  https://doaj.org/toc/826a1b161368467cad3ac6190...
# 19155  https://doaj.org/toc/6f40c9737dfb4eab8881600cb...
# 19156  https://doaj.org/toc/e366d1aee172433188fda8938...
# 19157  https://doaj.org/toc/a4f06be11f4f4db489dc034c7...
#
#        When did the journal start to publish all content using an open license?  \
# 0                                                 2000.0
# 1                                                 2014.0
# 2                                                 2000.0
# 3                                                 2017.0
# 4                                                 2019.0
# ...                                                  ...
# 19153                                             2022.0
# 19154                                             2022.0
# 19155                                             2022.0
# 19156                                             2022.0
# 19157                                             2001.0
#
#                                        Alternative title  \
# 0            Annals of the Brazilian Academy of Sciences
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 19153  Football(s): Histoire, Culture, Économie, Société
# 19154                                              IJHHR
# 19155               Papireto: Rivista Scientifica Online
# 19156                                                NaN
# 19157                                                NaN
#
#       Journal ISSN (print version) Journal EISSN (online version)  \
# 0                        0001-3765                      1678-2690
# 1                        0001-494X                      2282-0035
# 2                        0001-527X                      1734-154X
# 3                        0001-5555                      1651-2057
# 4                        0001-6012                      2215-5856
# ...                            ...                            ...
# 19153                    2967-0837                      2968-0115
# 19154                    2971-5121                            NaN
# 19155                          NaN                      2974-668X
# 19156                          NaN                      2975-3848
# 19157                    8755-6839                      2168-6009
#
#                                                 Keywords  \
# 0      biological sciences, exact and earth sciences,...
# 1      italian literature, classic literature, lingui...
# 2      molecular biology, biophysics, bioinformatics,...
# 3      sexually transmitted infections, psoriasis, ps...
# 4      medicine, public health, medical sciences, health
# ...                                                  ...
# 19153  history, study of politics, cultural history, ...
# 19154  home economics, hospitality management, allied...
# 19155  history of art, anthropology, aesthetics, arch...
# 19156  concrete structures, construction materials, h...
# 19157  tsunamis, tsunami warning systems, earthquakes...
#
#       Languages in which the journal accepts manuscripts  \
# 0                                                English
# 1                                                Italian
# 2                                                English
# 3                                                English
# 4                                       Spanish, English
# ...                                                  ...
# 19153                                             French
# 19154                                            English
# 19155                  Italian, English, Spanish, French
# 19156                                            English
# 19157                                            English
#
#                                                Publisher  ...  \
# 0                        Academia Brasileira de Ciências  ...
# 1                       Università degli Studi di Milano  ...
# 2                             Polish Biochemical Society  ...
# 3                                Medical Journals Sweden  ...
# 4           Colegio de Médicos y Cirujanos de Costa Rica  ...
# ...                                                  ...  ...
# 19153     Presses Universitaires de Franche-Comté (PUFC)  ...
# 19154  Department of Home Economics & Hospitality Man...  ...
# 19155  Dipartimento di Comunicazione e Didattica dell...  ...
# 19156  Josip Juraj Strossmayer University of Osijek, ...  ...
# 19157                      Tsunami Society International  ...
#
#                  URL for journal's Open Access statement  Continues  \
# 0        http://www.scielo.br/revistas/aabc/isubscrp.htm        NaN
# 1      http://riviste.unimi.it/index.php/ACME/about/e...        NaN
# 2         https://ojs.ptbioch.edu.pl/index.php/abp/about        NaN
# 3       https://medicaljournalssweden.se/actadv/oapolicy        NaN
# 4      http://actamedica.medicos.cr/index.php/Acta_Me...        NaN
# ...                                                  ...        ...
# 19153  https://preo.u-bourgogne.fr/football-s/index.p...        NaN
# 19154          https://www.ijhhr.org/open-access-policy/        NaN
# 19155       https://papireto.accademiadipalermo.it/info/        NaN
# 19156      https://hrcak.srce.hr/ojs/index.php/acae/copy  1847-8948
# 19157  http://tsunamisociety.org/InstructionsAuthors....        NaN
#
#       Continued By                 LCC Codes  \
# 0              NaN                         Q
# 1              NaN                         A
# 2              NaN       QD415-436|QH426-470
# 3              NaN                   RL1-803
# 4              NaN                         R
# ...            ...                       ...
# 19153          NaN  GV557-1198.995|HC10-1085
# 19154          NaN                  TX1-1110
# 19155          NaN         NX440-632|CC1-960
# 19156          NaN                  TA1-2040
# 19157          NaN                  GC1-1581
#
#                                                 Subjects DOAJ Seal  \
# 0                                                Science        No
# 1                                          General Works        No
# 2      Science: Chemistry: Organic chemistry: Biochem...        No
# 3                                  Medicine: Dermatology        No
# 4                                               Medicine        No
# ...                                                  ...       ...
# 19153  Geography. Anthropology. Recreation: Recreatio...        No
# 19154                         Technology: Home economics        No
# 19155  Fine Arts: Arts in general: History of the art...        No
# 19156  Technology: Engineering (General). Civil engin...        No
# 19157  Geography. Anthropology. Recreation: Oceanography        No
#
#               Added on Date     Last updated Date Number of Article Records  \
# 0      2004-04-23T21:31:00Z  2017-01-04T14:19:54Z                      3913
# 1      2014-12-22T19:55:58Z  2022-08-10T19:13:04Z                       224
# 2      2022-05-23T10:09:09Z  2022-05-23T10:09:09Z                         0
# 3      2011-11-10T12:31:05Z  2023-01-19T09:14:05Z                      1581
# 4      2020-12-22T11:08:24Z  2022-07-29T11:54:21Z                      1207
# ...                     ...                   ...                       ...
# 19153  2023-01-14T13:39:37Z  2023-01-14T13:39:37Z                         0
# 19154  2022-11-13T20:06:16Z  2022-11-19T14:23:23Z                        42
# 19155  2023-03-23T17:17:20Z  2023-03-23T17:17:20Z                        16
# 19156  2022-11-21T11:18:02Z  2022-11-21T11:18:02Z                         6
# 19157  2009-04-16T17:40:30Z  2022-04-28T14:50:44Z                       278
#
#       Most Recent Article Added
# 0          2023-03-28T07:31:32Z
# 1          2023-03-16T15:14:11Z
# 2                           NaN
# 3          2023-03-30T09:20:23Z
# 4          2015-12-08T15:06:43Z
# ...                         ...
# 19153                       NaN
# 19154      2023-01-01T16:55:03Z
# 19155      2023-03-23T21:46:16Z
# 19156      2023-01-04T12:01:11Z
# 19157      2022-12-20T20:16:02Z
#
# [19158 rows x 54 columns]

# %%
#create an extra column that extract the journal's domain,
# which will be used in the reverse dictionary
doaj["journal_domain"] = doaj["Journal URL"].apply(lambda x: tldextract.extract(x).domain)
doaj["journal_domain"]
# Out:
# 0                       scielo
# 1                        unimi
# 2                      ptbioch
# 3        medicaljournalssweden
# 4                      medicos
#                  ...
# 19153              u-bourgogne
# 19154                    ijhhr
# 19155       accademiadipalermo
# 19156                     srce
# 19157           tsunamisociety
# Name: journal_domain, Length: 19158, dtype: object

# %%
green_flags_dict = pd.Series(doaj["Journal URL"].values,index=doaj["Journal title"]).to_dict()
green_flags_reverse = pd.Series(doaj["Journal title"].values, index=doaj["journal_domain"]).to_dict()

# %%
# see the result to do a smoke test
green_flags_reverse
# Out:
# {'scielo': 'Revista Uruguaya de Medicina Interna',
#  'unimi': 'Dissertation Nursing',
#  'ptbioch': 'Acta Biochimica Polonica',
#  'medicaljournalssweden': 'Journal of Rehabilitation Medicine - Clinical Communications',
#  'medicos': 'Acta Médica Costarricense',
#  'pbsociety': 'Acta Agrobotanica',
#  'elsevier': 'Journal of Orthopaedic Reports',
#  'srce': 'Advances in Civil and Architectural Engineering',
#  'sagepub': 'Video Journal of Sports Medicine',
#  'ufba': 'Revista Direito e Sexualidade',
#  'revistaalergia': 'Revista Alergia México',
#  'ashs': 'HortScience',
#  'ceon': 'Bulletin of Natural Sciences Research',
#  'ul': 'ESTUDIO',
#  'allenpress': 'Innovations in Digital Health, Diagnostics, and Biomarkers',
#  'iaepan': 'Ethnologia Polona',
#  'archives-animal-breeding': 'Archives Animal Breeding',
#  'csic': 'Disparidades',
#  'sup': 'Archivos de Pediatría del Uruguay',
#  'uco': 'Seriarte',
#  'alanrevista': 'Archivos Latinoamericanos de Nutrición',
#  'ugr': 'Theory Now',
#  'aoa': 'Revista de la Asociación Odontológica Argentina',
#  'iop': 'ECS Advances',
#  'tandfonline': 'Cogent Public Health',
#  'contributions-to-entomology': 'Contributions to Entomology',
#  'brill': 'Al-Markaz: Majallat al-Dirāsāt al-ʿArabiyya',
#  'sciendo': 'Logistics, Supply Chain, Sustainability and Global Challenges',
#  'abcjournal': 'Bothalia: African Biodiversity & Conservation',
#  'fsb': 'Brodogradnja',
#  'ucanr': 'California Agriculture',
#  'fupress': 'QOE-IJES',
#  'cuni': 'Scientia in Educatione',
#  'cas': 'Cornova',
#  'chimia': 'CHIMIA',
#  'unito': 'European Journal of Social Impact and Circular Economy',
#  'unlp': 'Revista Electrónica de Derecho Internacional Contemporáneo',
#  'scu': 'Journal of Applied Research in Electrical Engineering',
#  'cirugiaycirujanos': 'Cirugía y Cirujanos',
#  'ems': 'Journal of Combinatorial Algebra',
#  'hkd': 'Croatica Chemica Acta',
#  'columbia': 'Meliora',
#  'darwin': 'Darwiniana',
#  'aerzteblatt': 'Deutsches Ärzteblatt',
#  'philosophie': 'Dialectica',
#  'drvnaindustrija': 'Drvna Industrija',
#  'unal': 'Ainkaa',
#  'idunn': 'Nordic Journal of Studies in Policing',
#  'springeropen': 'Fixed Point Theory and Algorithms for Sciences and Engineering',
#  'pte': 'Ekonomista',
#  'bg': 'Kritika',
#  'wiley': 'International Studies of Economics',
#  'ekt': 'Byzantina Symmeikta',
#  'epitoanyag': 'Építőanyag: Journal of Silicate Based and Composite Materials',
#  'die-erde': 'DIE ERDE: Journal of the Geographical Society of Berlin',
#  'unc': '1991. Revista de Estudios Internacionales',
#  'ptfarm': 'Farmacja Polska',
#  'tsv': 'Agricultural and Food Science',
#  'flvc': 'Journal of Postsecondary Student Success',
#  'fluorideresearch': 'Fluoride',
#  'revistadefomentosocial': 'Revista de Fomento Social',
#  'fysioterapeuten': 'Fysioterapeuten',
#  'gacetamedicademexico': 'Gaceta Médica de México',
#  'openedition': 'Humanités Numériques',
#  'gayanabotanica': 'Gayana: Botanica',
#  'geographica-helvetica': 'Geographica Helvetica',
#  'cambridge': 'European Law Open',
#  'geology-mgri': 'Известия высших учебных заведений: Геология и разведка',
#  'geologija-revija': 'Geologija',
#  'ghanamedj': 'Ghana Medical Journal',
#  'viamedica': 'Palliative Medicine in Practice',
#  'duke': 'Greek, Roman, and Byzantine Studies',
#  'biomedcentral': 'BMC Primary Care',
#  'hessische-blaetter': 'Hessische Blätter für Volksbildung',
#  'historickycasopis': 'Historický Časopis',
#  'icar': 'Journal of Sugarcane Research',
#  'ijaweb': 'Indian Journal of Anaesthesia',
#  'e-ijd': 'Indian Journal of Dermatology',
#  'niscpr': 'Indian Journal of Natural Products and Resources',
#  'indianjpsychiatry': 'Indian Journal of Psychiatry',
#  'ijph': 'Indian Journal of Public Health',
#  'springer': 'Carbon Neutrality',
#  'tetsutohagane': 'Tetsu to Hagane',
#  'iss': 'Bollettino Epidemiologico Nazionale',
#  'jci': 'JCI Insight',
#  'jpgmonline': 'Journal of Postgraduate Medicine',
#  'hdki': 'Kemija u Industriji',
#  'hirurgiya': 'Клінічна хірургія',
#  'koersjournal': 'Koers : Bulletin for Christian Scholarship',
#  'ip': 'Komunikaty Mazursko-Warmińskie',
#  'laeknabladid': 'Icelandic Medical Journal',
#  'landtechnik-online': 'Landtechnik',
#  'uba': 'Historia & Guerra',
#  'uni-lj': 'Stridon',
#  'hlz': 'Liječnički vjesnik',
#  'umk': 'Jurnal Dialektika Informatika',
#  'novus': 'Musikk og Tradisjon',
#  'ugm': 'Journal of Social Development Studies',
#  'math': 'Computer Science Journal of Moldova',
#  'lww': 'Annals of Surgery Open',
#  'jst': 'Biophysics and Physicobiology',
#  'micronesica': 'Micronesica',
#  'hs-hannover': 'Milk Science International',
#  'mta': 'Bulletin of the Mineral Research and Exploration',
#  'monetaecredito': 'Moneta e Credito',
#  'mosuljournals': 'مجلة الموصل للتمريض',
#  'pitt': 'Philosophy of Medicine',
#  'jnma': 'Journal of Nepal Medical Association',
#  'tidsskriftet': 'Tidsskrift for Den norske legeforening',
#  'ecu': 'North Carolina Libraries',
#  'thenucleuspak': 'The Nucleus',
#  'ojvr': 'Onderstepoort Journal of Veterinary Research',
#  'paediatricaindonesiana': 'Paediatrica Indonesiana',
#  'pafmj': 'Pakistan Armed Forces Medical Journal',
#  'pjmr': 'Pakistan Journal of Medical Research',
#  'jpma': 'Journal of the Pakistan Medical Association',
#  'ispan': 'Adeptus',
#  'pedcas': 'Pedagogika',
#  'comillas': 'Revista Iberoamericana de Bioética',
#  'matthey': 'Johnson Matthey Technology Review',
#  'polarforschung': 'Polarforschung',
#  'uio': 'Journal of Extreme Anthropology',
#  'pwr': 'Mining Science',
#  'pspaw': 'Przegląd Spawalnictwa',
#  'termedia': 'Physiotherapy Quarterly',
#  'hindawi': 'Advances in Pharmacological and Pharmaceutical Sciences',
#  'psychologicabelgica': 'Psychologica Belgica',
#  'revues': 'Babel: Littératures Plurielles',
#  'oekom': 'Raumforschung und Raumordnung',
#  'lipi': 'Jurnal Masyarakat dan Budaya',
#  'inca': 'Revista Brasileira de Cancerologia',
#  'inep': 'Revista Brasileira de Estudos Pedagógicos',
#  'ufmg': 'Fronteiras da Representação do Conhecimento',
#  'aborj': 'Revista Brasileira de Odontologia',
#  'biotaxa': 'Ecologica Montenegrina',
#  'fecolsog': 'Revista Colombiana de Obstetricia y Ginecología',
#  'sld': 'Revista Científica Estudiantil 2 de Diciembre',
#  'usp': 'GIS - Gesto, Imagem e Som - Revista de Antropologia',
#  'ucr': 'Nutrición Animal Tropical',
#  'uchile': 'Propuestas Críticas en Trabajo Social',
#  'ucm': 'Revista Española de Desarrollo y Cooperación',
#  'revistasipgh': 'Revista Cartográfica',
#  'clinicalandtranslationalinvestigation': 'Revista de Investigación Clínica',
#  'upch': 'Revista Herediana de Rehabilitación',
#  'ise': 'Revista de Pedagogie',
#  'upsa': 'Revista Española de Derecho Canónico',
#  'sipsych': 'Interamerican Journal of Psychology',
#  'cirad': 'Revue d’Elevage et de Médecine Vétérinaire des Pays Tropicaux',
#  'agroparistech': 'Revue Forestière Française',
#  'pagepress': 'Infectious Diseases and Herbal Medicine',
#  'pzh': 'Roczniki Panstwowego Zakladu Higieny',
#  'amu': 'Przegląd Krytyczny',
#  'saludpublica': 'Salud Pública de México',
#  'mdpi': 'Agrochemicals',
#  'sav': 'Contributions to Geophysics and Geodesy',
#  'journals': 'Jurnal Ilmu Sosial Humaniora Indonesia',
#  'uem': 'Journal of Physical Education',
#  'bsgf': 'BSGF - Earth Sciences Bulletin',
#  'nb': 'Panoeconomicus',
#  'sociologiskforskning': 'Sociologisk Forskning',
#  'sajs': 'South African Journal of Science',
#  'studiapsychologica': 'Studia Psychologica',
#  'studiasocjologiczne': 'Studia Socjologiczne',
#  'istoria-artei': "Revue Roumaine d'Histoire de l'Art : Série Beaux-Arts",
#  'taalentongval': 'Taal en Tongval: Language Variation in the Low Countries',
#  'ter-arkhiv': 'Терапевтический архив',
#  'journal': 'Finnish Journal of Social Research',
#  'berghahnjournals': 'Migration and Society',
#  'eltrimestreeconomico': 'El Trimestre Económico',
#  'letterkunde': 'Tydskrif vir Letterkunde',
#  'criba': 'Revista de la Unión Matemática Argentina',
#  'ufc': 'Informação em Pauta',
#  'javeriana': 'Magis: Revista Internacional de Investigación en Educación',
#  'uobaghdad': 'Baghdad Science Journal',
#  'pucrs': 'Scriptorium',
#  'vestnikdv': 'Vestnik Dermatologii i Venerologii',
#  'vestnik-grekova': 'Вестник хирургии имени И.И. Грекова',
#  'russianradiology': 'Вестник рентгенологии и радиологии',
#  'mod': 'Vojnotehnički Glasnik',
#  'stat': 'Wiadomości Statystyczne',
#  'ym-kdham': 'Yoga-Mimamsa',
#  'zapiskihistoryczne': 'Zapiski Historyczne',
#  '147.213.211.222': 'Životné prostredie',
#  'inra': 'Acarologia',
#  'tums': 'Current Journal of Neurology',
#  'cbs': 'Journal of Business Anthropology',
#  'architektura-urbanizmus': 'Architecture & Urbanism',
#  'emis': 'Symmetry, Integrability and Geometry: Methods and Applications',
#  'esg': 'Egyptian Journal of Genetics and Cytology',
#  'navarra': 'Fontes Linguae Vasconum',
#  'uclv': 'Revista Centro Azúcar',
#  'nzjforestryscience': 'New Zealand Journal of Forestry Science',
#  'pkheartjournal': 'Pakistan Heart Journal',
#  'da': 'The Philippine Journal of Fisheries',
#  'reumatismo': 'Reumatismo',
#  'revistarar': 'Revista Argentina de Radiología',
#  'uo': 'Anuario Facultad de Ciencias Económicas y Empresariales',
#  'lillo': 'Lilloa',
#  'ejournals': 'Studia Historiae Scientiarum',
#  'pan': 'Geodesy and Cartography',
#  'arheologiamoldovei': 'Arheologia Moldovei',
#  'australian': 'Records of the Australian Museum',
#  'iz': 'Boletim de Indústria Animal',
#  'uncu': 'Saberes y Prácticas: Revista de Filosofía y Educación',
#  'uc': 'Jurnal Performa',
#  'emnuvens': 'Brazilian Journal of Transplantation',
#  'produccioncientificaluz': 'Revista de la Universidad del Zulia',
#  'koedoe': 'Koedoe: African Protected Area Conservation and Science',
#  'mcajournal': 'Materiale și Cercetări Arheologice',
#  'karolinum': 'Historicka Sociologie',
#  'wnus': 'Acta Politica Polonica',
#  'schwabeonline': 'Studia Philosophica',
#  'tyndalebulletin': 'Tyndale Bulletin',
#  'lodz': 'Logopaedica Lodziensia',
#  'natalia': 'Natalia',
#  'nipr': 'Antarctic Record',
#  'noaa': 'Fishery Bulletin',
#  'nih': 'Environmental Health Perspectives',
#  'revistanavigator': 'Navigator',
#  'ibict': 'LALCA',
#  'rbmv': 'Brazilian Journal of Veterinary Medicine',
#  'ufrgs': 'Drug Analytical Research',
#  'ufersa': 'Revista Jurídica da Ufersa',
#  'revistadoilct': 'Revista do Instituto de Latícinios Cândido Tostes',
#  'unesp': 'Revista Fim do Mundo',
#  'bvsalud': 'Revista Psicologia',
#  'revodontolunesp': 'Revista de Odontologia da UNESP',
#  'unisc': 'Psi Unisc',
#  'metodista': 'Revista Organizações em Contexto',
#  'est': 'Protestantismo em Revista',
#  'uol': 'Pakistan Journal of Engineering & Technology',
#  'ufsc': 'Journal of Lean Systems',
#  'revistadae': 'Revista DAE',
#  'abas': 'Revista Águas Subterrâneas',
#  'ufg': 'Arte da Cena',
#  'unifor': 'Revista Subjetividades',
#  'uepg': 'Revista de estudios teóricos y epistemológicos en política educativa',
#  'ufpe': 'Revista Ensino de Geografia',
#  'tjdft': 'Revista de Doutrina Jurídica',
#  'ufsm': 'Revista Práticas de Administração Pública',
#  'ufrj': 'Inter',
#  'sabnet': 'Revista de Arqueologia',
#  'aph': 'Revista de Homeopatia',
#  'eb': 'Revista Agulhas Negras',
#  'fundaj': 'Ciência & Trópico',
#  'faje': 'Perspectiva Teológica',
#  'senac': 'Revista Brasileira de Gastronomia',
#  'unicamp': 'Modernos & Contemporâneos',
#  'arquivonacional': 'Acervo',
#  'furg': 'Campos Neutrais',
#  'pucsp': 'Revista Eletrônica do Departamento de Ciências Contábeis & Departamento de Atuária e Métodos Quantitativos',
#  'ufrn': 'Revista Projetar',
#  'revistadeeducacaofisica': 'Revista de Educação Física',
#  'unijui': 'Desenvolvimento em Questão',
#  'ufpel': 'Pixo',
#  'geobrasiliensis': 'Geochimica Brasiliensis',
#  'epagri': 'Agropecuária Catarinense',
#  'unisinos': 'Questões Transversais',
#  'ufu': 'Téssera',
#  'iflorestal': 'Revista do Instituto Florestal',
#  'ufjf': 'Revista de Investigação e Divulgação em Educação Matemática',
#  'unicuritiba': 'Administração de Empresas em Revista',
#  'bjstd': 'DST',
#  'classica': 'Classica, Revista Brasileira de Estudos Clássicos',
#  'sbq': 'Journal of the Brazilian Chemical Society',
#  'pucpr': 'Revista de Direito Econômico e Socioambiental',
#  'doi': 'Organic Materials',
#  'rbsh': 'Revista Brasileira de Sexualidade Humana',
#  'fcc': 'Estudos em Avaliação Educacional',
#  'ufal': 'Revista Contexto Geográfico',
#  'abralic': 'Revista Brasileira de Literatura Comparada',
#  'anppom': 'Opus',
#  'ines': 'Revista Forum',
#  'usf': 'Undergraduate Journal of Mathematical Modeling: One + Two',
#  'pucminas': 'Pretextos',
#  'rmmg': 'Revista Médica de Minas Gerais',
#  'cff': 'Infarma: Pharmaceutical Sciences',
#  'upf': 'Revista Brasileira de Ensino de Ciências e Matemática',
#  'ufpb': 'Revista Brasileira de Políticas Públicas e Internacionais',
#  'uerj': 'Revista Desenvolvimento e Civilização',
#  'ufpr': 'História do Direito',
#  'unoesc': 'RACE: Revista de Administração, Contabilidade e Economia',
#  'ufscar': 'Ensaios Pedagógicos',
#  'revbraspsicodrama': 'Revista Brasileira de Psicodrama',
#  'ufmt': 'Revista Estudos e Pesquisas em Administração',
#  'sbc': 'Journal on Interactive Systems',
#  'puc-rio': 'Ergodesign & HCI',
#  'revistanps': 'Nova Perspectiva Sistêmica',
#  'ufma': 'Terra de Pretos',
#  'variahistoria': 'Varia História',
#  'agricultura': 'Pesquisa Agropecuária Gaúcha',
#  'utfpr': 'ACTIO: Docência em Ciências',
#  'abo': 'ICO Iconographisk post',
#  'scholasticahq': 'Wine Business Journal',
#  'upd': 'Humanities Diliman',
#  'worldscientific': 'The Journal of Indian and Asian Studies',
#  'asianfisheriessociety': 'Asian Fisheries Science',
#  'udenar': 'Tendencias',
#  'uis': 'Cambios y Permanencias',
#  'dimar': 'Boletín Científico CIOH',
#  'udea': 'Uni-pluriversidad',
#  'udistrital': 'Góndola, Enseñanza y Aprendizaje de las Ciencias',
#  'upb': 'Colección Académica de Ciencias Sociales',
#  'sgc': 'Revista Investigaciones y Aplicaciones Nucleares',
#  'usb': 'اقتصاد باثبات',
#  'uptc': 'Educación y Ciencia',
#  'univalle': 'La Manzana de la Discordia',
#  'uniandes': 'Hart',
#  'pedagogica': 'Bio-grafía',
#  'revistabiomedica': 'Revista Biomédica',
#  'revistacontroversia': 'Revista Controversia',
#  'umariana': 'Revista Criterios',
#  'revistamedicina': 'Medicina',
#  'rccardiologia': 'Revista Colombiana de Cardiología',
#  'howjournalcolombia': 'HOW',
#  'udem': 'Ciencias Sociales y Educación',
#  'ucc': 'Revista Methodo',
#  'uexternado': 'Revista Digital de Derecho Administrativo',
#  'thieme': 'Global Medical Genetics',
#  'ean': 'Revista Escuela de Administracion de Negocios',
#  'eafit': 'Ricercare',
#  'usantotomas': 'Signos',
#  'unab': 'La Tercera Orilla',
#  'unisabana': 'Latin American Journal of Content and Language Integrated Learning',
#  'revistacmfr': 'Revista Colombiana de Medicina Física y Rehabilitación',
#  'unimilitar': 'Academia y Virtualidad',
#  'juanncorpas': 'Revista Cuarzo',
#  'uninorte': 'Salud Uninorte',
#  'unaula': 'Ratio Juris',
#  'autonoma': 'Psique',
#  'fucsalud': 'Repertorio de Medicina y Cirugía',
#  'ucentral': 'Rumbos TS',
#  'ucaldas': 'Revista Latinoamericana de Estudios de Familia',
#  'unicordoba': 'Assensus',
#  'sena': 'Revista Colombiana de Investigaciones Agroindustriales',
#  'latinjournal': 'GiST Education and Learning Research Journal',
#  'ecopetrol': 'CT&F Ciencia, Tecnología & Futuro',
#  'cuc': 'Cultura, Educación,  Sociedad',
#  'unicartagena': 'Revista Ciencias Biomédicas',
#  'lasalle': 'Ciencia y Tecnología para la Salud Visual y Ocular',
#  'idep': 'Educación y Ciudad',
#  'uan': 'Revista Tamé',
#  'medicinaylaboratorio': 'Medicina y Laboratorio',
#  'umanizales': 'Tempus Psicológico',
#  'udca': 'Revista Digital: Actividad Física y Deporte',
#  'icesi': 'Trans-pasando Fronteras',
#  'itm': 'Revista CEA',
#  'ibero': 'Sobre México',
#  'urosario': 'Anuario Iberoamericano de Derecho Internacional Penal',
#  'ucatolica': 'Cultura Latinoamericana',
#  'uniguajira': 'Entretextos',
#  'revistainfectio': 'Infectio',
#  'cecar': 'Búsqueda',
#  'unilibre': 'Arista Crítica',
#  'unisimon': 'Investigación e Innovación en Ingenierías',
#  'uniminuto': 'Inclusión & Desarrollo',
#  'unicauca': 'Biotecnología en el Sector Agropecuario y Agroindustrial',
#  'unbosque': 'Revista Salud Bosque',
#  'humboldt': 'Biota Colombiana',
#  'ucn': 'Cepra-Striben',
#  'mahidol': 'Pharmaceutical Sciences Asia',
#  'psu': 'Vestnik Permskogo universiteta: Rossijskaâ i zarubežnaâ filologiâ',
#  'tci-thaijo': 'Science Technology and Engineering Journal (STEJ)',
#  'iribb': 'Menara Perkebunan',
#  'actamedindones': 'Acta Medica Indonesiana',
#  'ui': 'پژوهش\u200cهای راهبردی مسائل اجتماعی ایران',
#  'depkes': 'Health Science Journal of Indonesia',
#  'aljamiah': "Al-Jami'ah: Journal of Islamic Studies",
#  'ipb': 'Tropical Animal Science Journal',
#  'ub': 'Journal of Interdisciplinary Socio Economic and Community Study',
#  'uny': 'Jurnal Penelitian dan Evaluasi Pendidikan',
#  'unpad': 'Tourism and Sustainable Development Review',
#  'asia': 'Jurnal Ilmiah Bisnis dan Ekonomi Asia',
#  'batan': 'Ganendra: Majalah IPTEK Nuklir',
#  'cria': 'Contributions of Central Research Institute for Agriculture',
#  'unand': 'Andalasian International Journal of Applied Science, Engineering, and Technology',
#  'petra': 'JIRAE (International Journal of Industrial Research and Applied Engineering)',
#  'tufs': 'Nusa',
#  'ijconline': 'Majalah Kardiologi Indonesia',
#  'ukm': 'Asia-Pacific Journal of Information Technology and Multimedia',
#  'iemjournal': 'Journal of the Institution of Engineers, Malaysia',
#  'gsm': 'Bulletin of the Geological Society of Malaysia',
#  'um': 'مهندسی عمران فردوسی',
#  'usm': 'International Journal of Language, Literacy and Translation',
#  'maltesas': 'MALTESAS Multi-Disciplinary Research Journal',
#  'wildlife': 'Journal of Wildlife and Parks',
#  'uitm': 'Journal of Smart Science and Technology',
#  'deerhillpublishing': 'International Journal of Engineering Materials and Manufacture',
#  'inceif': 'ISRA International Journal of Islamic Finance',
#  'uum': 'The International Journal of Banking and Finance',
#  'vu': 'Information & Media',
#  'baltistica': 'Baltistica',
#  'computeroptics': 'Компьютерная оптика',
#  'esoil': 'Бюллетень Почвенного института им. В.В. Докучаева',
#  'pensoft': 'Vegetation Classification and Survey (VCS)',
#  'us': 'Paidia i Literatura',
#  'academicon': 'Nasza Przeszłość',
#  'umcs': 'Przegląd Prawa Administracyjnego',
#  'pts': 'Studia Semiotyczne',
#  'uwm': 'Civitas et Lex',
#  'uksw': 'Refleksi Hukum',
#  'revistasgeotech': 'Poeyana',
#  'mtak': 'Tánc és Nevelés',
#  'agriculturejournals': 'Soil and Water Research',
#  'portlandpress': 'Neuronal Signaling',
#  'newprairiepress': 'Health Behavior Research',
#  'uv': 'Hybrida',
#  'filmcriticismjournal': 'Film Criticism',
#  'bmgn-lchr': 'BMGN: Low Countries Historical Review',
#  'knob': 'Bulletin KNOB',
#  'sciencedirect': 'Theriogenology Wild',
#  'rivista-incontri': 'Incontri: Rivista Europea di Studi Italiani',
#  'ntnu': 'Dance Articulated',
#  'colmex': 'Revista Interdisciplinaria de Estudios de Género de El Colegio de México',
#  'hospitalgeneral': 'Revista Médica del Hospital General de México',
#  'unam': 'Nuevas Poligrafías, Revista de Teoría Literaria y Literatura Comparada',
#  'anuies': 'Revista de la Educación Superior',
#  'cienciasmarinas': 'Ciencias Marinas',
#  'uam': 'Biblioteca de Babel',
#  'trace': 'Trace',
#  'mora': 'América Latina en la Historia Económica',
#  'actapediatrica': 'Acta Pediátrica de México',
#  'rmo': 'Revista Mexicana de Oftalmología',
#  'perinatologia': 'Perinatología y Reproducción Humana',
#  'terralatinoamericana': 'Terra Latinoamericana',
#  'uabc': 'Revista de Ciencias Tecnológicas',
#  'inecol': 'Acta Botanica Mexicana',
#  'colef': 'Migraciones Internacionales',
#  'revistatyca': 'Tecnología y ciencias del agua',
#  'ciad': 'Estudios Sociales',
#  'anahuac': 'Sintaxis',
#  'ugto': 'Valenciana',
#  'up': 'Teacher Education through Flexible Learning in Africa',
#  'flacso': 'Perfiles Latinoamericanos',
#  'ucol': 'Avances en Investigación Agropecuaria',
#  'uacj': 'Chihuahua Hoy',
#  'afrjpaedsurg': 'African Journal of Paediatric Surgery',
#  'auburn': 'The Professional Educator',
#  'foliamedica': 'Folia Medica',
#  'naim': 'Приноси към българската археология',
#  'nmnhs': 'Historia naturalis bulgarica',
#  'kantiana': 'Слово.ру: балтийский акцент',
#  'eap': 'Research Papers in Language Teaching and Learning',
#  'marszalek': 'Nowa Polityka Wschodnia',
#  'tnkul': 'Journal for Perspectives of Economic Political and Social Integration',
#  'wiedzaobronna': 'Wiedza Obronna',
#  'ptt': 'Ruch Biblijny i Liturgiczny',
#  'internationalrelations-publishing': 'Stosunki Międzynarodowe',
#  'polsl': 'Transport Problems',
#  'komag': 'Mining Machines',
#  'czasopismowst': 'Warszawskie Studia Teologiczne',
#  'fuesp': 'Ihering',
#  'revesppod': 'Revista Española de Podología',
#  'uloyola': 'Archivo Teológico Granadino',
#  'usal': 'Popular Music Research Today',
#  'uab': 'Quaderns IEE',
#  'ief': 'Crónica Tributaria',
#  'age-geografia': 'Boletín de la Asociación de Geógrafos Españoles',
#  'cis': 'Revista Española de Investigaciones Sociológicas (REIS)',
#  'atlantisjournal': 'Atlantis',
#  'unex': 'Revista de Investigación en Didáctica de las Ciencias Sociales',
#  'unirioja': 'Revista Internacional DIGILEC',
#  'iec': "Comunicació: Revista de Recerca i d'Anàlisi",
#  'psicologicajournal': 'Psicológica',
#  'analisi': 'Anàlisi: Quaderns de Comunicació i Cultura',
#  'quadernsdepsicologia': 'Quaderns de Psicología',
#  'revistaaen': 'Revista de la Asociación Española de Neuropsiquiatría',
#  'uma': 'مدل\u200cسازی و مدیریت آب و خاک',
#  'euskadi': 'Revista Vasca de Gestión de Personas y Organizaciones Públicas',
#  'uned': 'Revista Humanidades Digitales',
#  'urv': 'Revista Internacional de Lenguas Extranjeras',
#  'revistadebats': 'Debats. Revista de cultura, poder i societat',
#  'nutricionhospitalaria': 'Nutrición Hospitalaria',
#  'rld': 'Revista de Llengua i Dret - Journal of Language and Law',
#  'man': 'Boletín del Museo Arqueológico Nacional',
#  'ua': 'UOU Journal',
#  'uniovi': 'SELIM',
#  'cortesgenerales': 'Revista de las Cortes Generales',
#  'ulpgc': 'Philologica Canariensia',
#  'scipedia': 'Revista Internacional de Métodos Numéricos para Cálculo y Diseño en Ingeniería',
#  'unileon': 'Sinología Hispanica',
#  'revistacarthaginensia': 'Carthaginensia',
#  'investigacionesgeograficas': 'Investigaciones Geográficas',
#  'limnetica': 'Limnetica',
#  'fecyt': 'Retos: Nuevas Tendencias en Educación Física, Deportes y Recreación',
#  'ujaen': 'Revista Internacional de Apoyo a la Inclusión, Logopedia, Sociedad y Multiculturalidad',
#  'gacetasanitaria': 'Gaceta Sanitaria',
#  'eurjhm': 'European Journal of Human Movement',
#  'reugra': 'Revista de Educación de la Universidad de Granada',
#  'uhu': 'Revista Iberoamericana de Economía Solidaria e Innovación Socioecológica',
#  'gazeta-antropologia': 'Gazeta de Antropología',
#  'aranzadi': 'Munibe Ciencias Naturales',
#  'papelesdelpsicologo': 'Papeles del Psicólogo',
#  'revistacaplletra': 'Caplletra: Revista Internacional de Filologia',
#  'udl': 'Imago Temporis: Medium Aevum',
#  'infad': 'INFAD',
#  'psicothema': 'Psicothema',
#  'ccrjournal': 'Coffee and Cocoa Research Journal',
#  'pertanian': 'Jurnal Ilmu Ternak dan Veteriner',
#  'coconutcommunity': 'CORD',
#  'uad': 'Epidemiology and Society Health Review',
#  'uinjkt': 'Insaniyat: Journal of Islam and Humanities',
#  'biotrop': 'Biotropia: The Southeast Asian Journal of Tropical Biology',
#  'teflin': 'TEFLIN Journal',
#  'uin-antasari': 'Jurnal Studia Insania',
#  'unair': 'Indonesian Journal of Dental Medicine',
#  'unud': 'Journal of Electrical, Electronics and Informatics',
#  'wartaardhia': 'Warta Ardhia: Jurnal Perhubungan Udara',
#  'unnes': 'Indonesian Journal of Pancasila and Global Constitutionalism',
#  'kursorjournal': 'Jurnal Ilmiah Kursor: Menuju Solusi Teknologi Informasi',
#  'forda-mof': 'Jurnal Perbenihan Tanaman Hutan',
#  'unpar': 'Jurnal Ilmiah Hubungan Internasional',
#  'kemdikbud': 'Jurnal Pendidikan dan Kebudayaan',
#  'unj': 'Perduli',
#  'unsoed': 'J-Lalite',
#  'upnvj': 'Journal of Islamic Economics and Finance Studies',
#  'unikama': 'Jurnal Bidang Pendidikan Dasar',
#  'trisakti': 'Media Ekonomi',
#  'umy': 'Journal of Islamic Economic and Business Research',
#  'poltekeskupang': 'Jurnal Info Kesehatan',
#  'jurnaliainpontianak': 'Al-Albab',
#  'untag-sby': 'Persona',
#  'unihaz': 'Buletin Agroteknologi',
#  'unissula': 'Ulul Albab: Jurnal Studi dan Penelitian Hukum Islam',
#  'smujo': 'Nusantara Bioscience',
#  'umm': 'Research and Development in Education',
#  'gontor': 'Agroindustrial Technology Journal',
#  'trunojoyo': 'Simulacra',
#  'pnb': 'Journal of Applied Sciences in Travel and Hospitality',
#  'ajstd': 'ASEAN Journal on Science and Technology for Development',
#  'imrpress': 'Frontiers in Bioscience-Landmark',
#  'nus': 'The Asia Pacific Scholar',
#  'yorku': 'Witness',
#  'ovgu': 'Technische Mechanik',
#  'arheologia': 'Археологія',
#  'ophthalmosurgery': 'Офтальмохирургия',
#  'plit-periodical': 'Процессы литья',
#  'imeko': 'Acta IMEKO',
#  'elte': 'Historical Studies on Central Europe',
#  'rkk': 'Tér és Társadalom',
#  'zeszytynaukowe-sgsp': 'Zeszyty Naukowe SGSP',
#  'ibe': 'Edukacja',
#  'actavet': 'Acta Veterinaria Eurasia',
#  'dergipark': 'Darulhadis İslami Araştırmalar Dergisi',
#  'eure': 'EURE (Santiago) - Revista Latinoamericana de Estudios Urbano Regionales',
#  'hamdardislamicus': 'Hamdard Islamicus',
#  'dreamhosters': 'Estudios Paraguayos',
#  'pucp': 'Revista Kawsaypacha',
#  'uh': 'Alcance',
#  'ucsp': 'Allpanchis',
#  'sums': 'Iranian Journal of Colorectal Research',
#  'uobasrah': 'Basrah Journal of Surgery',
#  'mtkxjs': 'Meitan kexue jishu',
#  'sinap': 'Fushe yanjiu yu fushe gongyi xuebao',
#  'cujae': 'Revista Ciencia y Construcción',
#  'cnic': 'Revista CENIC Ciencias Químicas',
#  'censa': 'Revista de Protección Vegetal',
#  'kjmycology': '한국균학회지',
#  'qscience': 'Rule of Law and Anti-Corruption Center Journal',
#  'pvj': 'Pakistan Veterinary Journal',
#  'revistacubanadefisica': 'Revista Cubana de Física',
#  'xinyixue': 'Xin yixue',
#  'jnrc': 'He huaxue yu fangshe huaxue',
#  'mtxb': 'Meitan xuebao',
#  'ctv-jve-journal': 'Ciência e Técnica Vitivinícola',
#  'ykcs': 'Yankuang ceshi',
#  'unphu': 'AULA Revista de Humanidades y Ciencias Sociales',
#  'muet': 'Mehran University Research Journal of Engineering and Technology',
#  'aerc': 'Pakistan Journal of Applied Economics',
#  'revistatransilvania': 'Transilvania',
#  'cercetari-arheologice': 'Cercetări Arheologice',
#  'notulaebotanicae': 'Notulae Botanicae Horti Agrobotanici Cluj-Napoca',
#  'sajournalofeducation': 'South African Journal of Education',
#  'unisapressjournals': 'Southern African Business Review',
#  'annsaudimed': 'Annals of Saudi Medicine',
#  'ajol': "Journal de la Faculté de Médecine d'Oran",
#  'samj': 'South African Medical Journal',
#  'rcps-cr': 'Revista Costarricense de Psicología',
#  'ancientscienceoflife': 'Ancient Science of Life',
#  'ufs': 'Conci',
#  'literator': 'Literator',
#  'arphahub': 'Journal of the Bulgarian Geographical Society',
#  'sajip': 'SA Journal of Industrial Psychology',
#  'reduc': 'Ciencia y Deporte',
#  'sanp': 'Swiss Archives of Neurology, Psychiatry and Psychotherapy',
#  'chinaaet': 'Dianzi Jishu Yingyong',
#  'icemtl': 'Peuce',
#  'ukzn': 'Journal of Education',
#  'hts': 'HTS Teologiese Studies/Theological Studies',
#  'areeo': 'Journal of Medicinal Plants and By-products',
#  'journal-of-micropalaeontology': 'Journal of Micropalaeontology',
#  'ubplj': 'The Denning Law Journal',
#  'iwaponline': 'Water Quality Research Journal',
#  'msstate': 'Journal of Human Sciences and Extension',
#  'afonet': 'Journal of Field Ornithology',
#  'mrd-journal': 'Mountain Research and Development',
#  'kona': 'KONA Powder and Particle Journal',
#  'publications-prairial': 'Voix Contemporaines',
#  'aucgeographica': 'Acta Universitatis Carolinae Geographica',
#  'karger': 'The Saudi Journal of Health Systems Research',
#  'actagastro': 'Acta Gastroenterológica Latinoamericana',
#  'ujms': 'Upsala Journal of Medical Sciences',
#  'ijo': 'International Journal of Ophthalmology',
#  'sajae': 'South African Journal of Agricultural Extension',
#  'travaux-racovitza': "Travaux de l'Institut de Speologie Emile Racovitza",
#  'nanzan-u': 'Asian Ethnology',
#  'galiciaclinica': 'Galicia Clínica',
#  'cjphysiology': 'Chinese Journal of Physiology',
#  'banglajol': 'Delta Medical College Journal',
#  'oup': 'Life Metabolism',
#  'leprosyreview': 'Leprosy Review',
#  'nps': 'Australian Prescriber',
#  'cjhe-rces': 'Canadian Journal of Higher Education',
#  'dal': 'The Journal for Undergraduate Ethnography',
#  'lnu': 'Meta-Psychology',
#  'urfu': 'Journal of Tax Reform',
#  'czso': 'Statistika: Statistics and Economy Journal',
#  'archeologickerozhledy': 'Archeologické Rozhledy',
#  'iir': 'Актуальні проблеми міжнародних відносин',
#  'bme': 'Periodica Polytechnica: Mechanical Engineering',
#  'meteorologica': 'Meteorologica',
#  'saantropologia': 'Relaciones de la Sociedad Argentina de Antropología',
#  'revistasad': 'Revista de la Sociedad Argentina de Diabetes',
#  'caea': 'Scripta Ethnologica',
#  '200.16.86.39': 'Res Gesta',
#  'ciipme-conicet': 'Interdisciplinaria',
#  'unne': 'De Prácticas y Discursos',
#  'inta': 'RIA: Revista Investigaciones Agropecuarias',
#  'analisisfilosofico': 'Análisis Filosófico',
#  'uncoma': 'Quintú Quimün',
#  'uca': 'Revista de Estudios Jurídicos y Criminológicos',
#  'revistarenal': 'Revista de Nefrología, Diálisis y Trasplante',
#  'caicyt': 'Kimün. Revista Interdisciplinaria de Formación Docente',
#  'unr': 'Cuadernos del CURIHAM',
#  'unicen': 'Revista Estudios Ambientales',
#  'unju': 'Cuadernos de la Facultad de Humanidades y Ciencias Sociales: Universidad Nacional de Jujuy',
#  'dominguezia': 'Dominguezia',
#  'horticulturaar': 'Horticultura Argentina',
#  'fisica': 'Anales (Asociación Física Argentina)',
#  'rosario-conicet': 'Avances del Cesor',
#  'reumatologia': 'Revista Argentina de Reumatología',
#  'unl': 'Revista Eurolatinoamericana de Derecho Administrativo',
#  'revistamedicaderosario': 'Revista Médica de Rosario',
#  'ecologiaaustral': 'Ecología Austral',
#  'uner': 'Del Prudente Saber y el Máximo Posible de Sabor',
#  'unse': 'Trabajo y Sociedad',
#  'unlpam': 'Cuadernos de Extensión Universitaria de la UNLPam',
#  'mdp': 'El Jardín de los Poetas',
#  'revistahematologia': 'Hematología',
#  'historiaregional': 'Historia Regional',
#  'unsta': 'Itinerantes',
#  'nijotech': 'Nigerian Journal of Technology',
#  'iraal': 'Teanga: The Journal of the Irish Association for Applied Linguistics',
#  'mic-journal': 'Modeling, Identification and Control',
#  'uit': 'Borealis: An International Journal of Hispanic Linguistics',
#  'degruyter': 'Interkulturelles Forum der deutsch-chinesischen Kommunikation',
#  'spk-berlin': 'Iberoamericana. América Latina - España - Portugal',
#  'germanjournalsportsmedicine': 'Deutsche Zeitschrift für Sportmedizin',
#  'barnboken': 'Barnboken: Tidskrift för Barnlitteraturforskning',
#  'ekonomika': 'Ekonomika',
#  'unizg': 'Proceedings from the Scientific Conference Methodology and Archaeometry',
#  'uns': 'Journal of Law, Society, and Islamic Civilization',
#  'casopis-gradjevinar': 'Građevinar',
#  'ipu': 'Radovi Instituta za Povijest Umjetnosti',
#  'unsa': 'Radovi Šumarskog Fakulteta Univerziteta u Sarajevu',
#  'knjizevnaistorija': 'Књижевна историја',
#  'srl': 'Slavistična Revija',
#  'sanu': 'Theoretical and Applied Mechanics',
#  'balcanica': 'Balcanica',
#  'uniri': 'Politehnika',
#  'geodetski-vestnik': 'Geodetski Vestnik',
#  'zrc-sazu': 'De Musica Disserenda',
#  'idk': 'Zaštita Materijala',
#  'inovacijeunastavi': 'Inovacije u Nastavi',
#  'istorija20veka': 'Istorija 20. Veka',
#  'sociolosko-drustvo': 'Družboslovne Razprave',
#  'gfz': 'Geofizika',
#  'pravni-fakultet': 'Pravo',
#  'unist': 'Zbornik radova Filozofskog fakulteta u Splitu',
#  'shd-pub': 'Journal of the Serbian Chemical Society',
#  'midem-drustvo': 'Informacije MIDEM',
#  'fkit': 'Chemical and Biochemical Engineering Quarterly',
#  'eap-iea': 'Etnoantropološki Problemi',
#  'unios': 'Southeastern European Medical Journal',
#  'ni': 'Facta Universitatis. Series, Teaching, Learning and Teacher Education',
#  'ffri': 'European Journal of Analytic Philosophy',
#  'fpz': 'Promet (Zagreb)',
#  'hazu': 'Poredbeno Pomorsko Pravo',
#  'uirs': 'Urbani Izziv',
#  'cmj': 'Croatian Medical Journal',
#  'serbiosoc': 'Archives of Biological Sciences',
#  'ips': 'Srpska Politička Misao',
#  'istorije': 'Токови историје',
#  'savezenergeticara': 'Energija, Ekonomija, Ekologija',
#  'fink': 'Tribology in Industry',
#  'vinca': 'Thermal Science',
#  'sjweh': 'Scandinavian Journal of Work, Environment & Health',
#  'uefs': 'A Cor das Letras',
#  'actapeloritana': 'Atti della Accademia Peloritana dei Pericolanti : Classe di Scienze Fisiche, Matematiche e Naturali',
#  'botanic': 'Acta Botanica Croatica',
#  'uniroma1': 'Novecento Transnazionale',
#  'pharmj': 'Фармацевтичний журнал',
#  'geologinenseura': 'Bulletin of the Geological Society of Finland',
#  'ache': 'Chemical Industry and Chemical Engineering Quarterly',
#  'punjab': 'Journal of Agricultural Research',
#  'wroc': 'Pielęgniarstwo i Zdrowie Publiczne',
#  'microbe': 'Проблемы особо опасных инфекций',
#  'raccefyn': 'Revista de la Academia Colombiana de Ciencias Exactas, Físicas y Naturales',
#  'srpskiarhiv': 'Srpski Arhiv za Celokupno Lekarstvo',
#  'co': 'Cultura Física y Deportes de Guantánamo',
#  'veterinaria-sarajevo': 'Veterinaria',
#  'crie': 'Вопросы вирусологии',
#  'unict': 'Annali della Facoltà di Scienze della Formazione Università degli Studi di Catania',
#  'konkoly': 'Information Bulletin on Variable Stars',
#  'revistamedicahondurena': 'Revista Médica Hondureña',
#  'sasas': 'South African Journal of Animal Science',
#  'ciplaslatin': 'Cirugía Plástica Ibero-Latinoamericana',
#  'kjponline': 'Kerala Journal of Psychiatry',
#  'rmangiologia': 'Revista Mexicana de Angiología',
#  'ijpmonline': 'Indian Journal of Pathology and Microbiology',
#  'mag': 'Agronomía Costarricense',
#  'istanbul': 'Maliye Çalışmaları Dergisi',
#  'theologiaviatorum': 'Theologia Viatorum',
#  'unmsm': 'Espiral',
#  'intec': 'Ciencia y Salud',
#  'tec': 'e-Agronegocios',
#  'sabinet': 'South African Journal of Chemistry',
#  'sajp': 'South African Journal of Psychiatry',
#  'sajcd': 'South African Journal of Communication Disorders',
#  'curationis': 'Curationis',
#  'sociedadcientifica': 'Revista de la Sociedad Científica del Paraguay',
#  'j-ca': 'Myakkangaku',
#  'j-mac': 'Maketingu Janaru',
#  'unibo': 'Finzioni',
#  'haematologica': 'Haematologica',
#  'rtsa': 'Transylvanian Review of Administrative Sciences',
#  'pediatrmedchir': 'La Pediatria Medica e Chirurgica',
#  'actaitalica': 'Acta Otorhinolaryngologica Italica',
#  'italian-journal-of-mammalogy': 'Hystrix, the Italian Journal of Mammalogy',
#  'ilcastellodielsinore': 'Il castello di Elsinore',
#  'avocetta': 'Avocetta',
#  'eg': 'Journal of Medicine in Scientific Research',
#  'deusto': 'Deusto Journal of Human Rights',
#  'abdn': 'Education in the North',
#  'eg-quaternary-science-journal': 'Eiszeitalter und Gegenwart',
#  'openlibhums': 'The Parish Review',
#  'iiu': 'International Journal of Distance Education and E-Learning',
#  'rcaap': 'Revista Jurídica Portucalense',
#  'geology': 'Geologické práce. Správy',
#  'hdko': 'Koža i Obuća',
#  'ontu': 'Zernovì Produkti ì Kombìkorma',
#  'lekovitesirovine': 'Lekovite Sirovine',
#  'leskovackizbornik': 'Лесковачки зборник',
#  'muzealnictworocznik': 'Muzealnictwo',
#  'isciii': 'Enfermería Nefrológica',
#  'nasemore': 'Naše More (Dubrovnik)',
#  'umin': 'Journal of Physical Fitness and Sports Medicine',
#  'putisaobracaj': 'Put i Saobraćaj',
#  'icanh': 'Fronteras de la Historia',
#  'ehu': 'AusArt',
#  'chinacrops': 'Zuowu xuebao',
#  'izs': 'Veterinaria Italiana',
#  'eymj': 'Yonsei Medical Journal',
#  'planejamento': 'Boletim Geográfico do Rio Grande do Sul',
#  'revistapediatria': 'Revista del Hospital de Niños',
#  'ulakbim': 'İstanbul Üniversitesi Orman Fakültesi Dergisi',
#  'anh': 'Investigaciones y Ensayos',
#  'bmhim': 'Boletín Médico del Hospital Infantil de México',
#  'carnet': 'Metalurgija',
#  'agricultforest': 'Poljoprivreda i Šumarstvo',
#  'unisalento': 'Community Psychology in Global Perspective',
#  'apl': 'Boletín de la Academia Peruana de la Lengua',
#  'unioviedo': 'Res Mobilis: International Research Journal of Furniture and Decorative Objects',
#  'imist': 'Moroccan Journal of Quantitative and Qualitative Research',
#  'uu': 'Scripta Islandica',
#  'unideb': 'Central European Journal of Educational Research',
#  'mimesisedizioni': 'Studi di Estetica',
#  'ffzg': 'Suvremena Lingvistika',
#  'msvu': 'Atlantis',
#  'alternateroutes': 'Alternate routes: a journal of Critical Social Research',
#  'uwindsor': 'Collected Essays on Learning and Teaching',
#  'uct': 'Journal of Construction Business and Management',
#  'arquitecturasdelsur': 'Arquitecturas del Sur',
#  'ricuc': 'Revista de Ingeniería de Construcción',
#  'revistachilenadeanestesia': 'Revista Chilena de Anestesia',
#  'conicyt': 'Universum',
#  'ucsh': 'Literatura y Lingüística',
#  'politicayestrategia': 'Política y Estrategia',
#  'userena': 'Logos: Revista de Lingüística, Literatura y Filosofía',
#  'ufro': 'Revista de Lenguas y Literatura Indoamericanas',
#  'psykhe': 'Psykhe',
#  'revistanotashistoricasygeograficas': 'Notas Históricas y Geográficas',
#  'academia': 'Actos',
#  'resochradi': 'Revista Chilena de Radiología',
#  'revistaiepraxis': 'Ius et Praxis',
#  'ubiobio': 'Ingenieria Industrial',
#  'revistaurbano': 'Urbano',
#  'clei': 'CLEI Electronic Journal',
#  'usach': 'Culturas Cientificas',
#  'medwave': 'Medwave',
#  'gayana': 'Gayana',
#  'rexe': 'Revista de Estudios y Experiencias en Educación',
#  'rechog': 'Revista Chilena de Obstetricia y Ginecología',
#  'psicoperspectivas': 'Psicoperspectivas',
#  'magallania': 'Magallania',
#  'gerflint': 'Synergies Portugal',
#  'arsmedica': 'Ars Medica',
#  'utalca': 'Revista Interamericana de Ambiente y Turismo',
#  'jotmi': 'Journal of Technology Management & Innovation',
#  'sisomosamericanos': 'Si Somos Americanos',
#  'neumologia-pediatrica': 'Neumología Pediátrica',
#  'journalmbr': 'Multidisciplinary Business Review',
#  'cnps': 'Cuadernos de Neuropsicologia',
#  'capicreview': 'Capic Review',
#  'revistaculturayreligion': 'Revista Cultura & Religión',
#  'izquierdas': 'Izquierdas',
#  'lajar': 'Latin American Journal of Aquatic Research',
#  'encrucijadaamericana': 'Revista Encrucijada Americana',
#  'boletinmuseoprecolombino': 'Boletín del Museo Chileno de Arte Precolombino',
#  'andeangeology': 'Andean Geology',
#  'udp': 'Cogency',
#  'cenaltes': 'Dorsal',
#  'executivebs': 'Avances en Ciencias e Ingeniería',
#  'revistariem': 'Revista Iberoamericana de Estudios Municipales',
#  'revistaestudioshemisfericosypolares': 'Revista Estudios Hemisféricos y Polares',
#  'uvigo': 'Revista Electrónica de Enseñanza de las Ciencias (REEC)',
#  'revistahabitatsustentable': 'Revista Hábitat Sustentable',
#  'historia396': 'Historia 396',
#  'techo': 'Revista CIS',
#  'jnrd': 'Journal of Natural Resources and Development',
#  'joralres': 'Journal of Oral Research',
#  'revistanuestramerica': 'Revista nuestrAmérica',
#  'utem': 'International Journal of Electrical Engineering and Applied Sciences',
#  'cuadernos': 'Cuadernos.info',
#  'jppres': 'Journal of Pharmacy & Pharmacognosy Research',
#  'revistainclusiones': 'Revista Inclusiones',
#  'revistamutatismutandis': 'Mutatis Mutandis: Revista Internacional de Filosofía',
#  'biodiversnathist': 'Biodiversity and Natural History',
#  'revistarivar': 'RIVAR',
#  'sophiaaustral': 'Sophia Austral',
#  '100cs': '100-Cs',
#  'tscuadernosdetrabajosocial': 'TS Cuadernos de Trabajo Social',
#  'cuadernosdearteprehistorico': 'Cuadernos de Arte Prehistórico',
#  'udla': 'Revista Educación Las Américas',
#  'inacap': 'Revista Gestión de la  Innovación en Educación Superior',
#  'celei': 'Polyphonía',
#  'udec': 'Revista Territorio y Regionalismos',
#  'autoctonia': 'Autoctonía',
#  'rchri': 'Revista Chilena de Relaciones Internacionales',
#  'revistareder': 'REDER',
#  'revistasaludybienestarcolectivo': 'Salud y Bienestar Colectivo',
#  'uai': 'Revista Abierta de Informática Aplicada',
#  'uautonoma': 'Journal of Management and Business Studies',
#  'uach': 'Debates por la Historia',
#  'amoxtli': 'Amoxtli',
#  'bc': 'Dianoia',
#  'future-science': 'Future Drug Discovery',
#  'newhaven': 'American Business Review',
#  'bsglg': 'Bulletin de la Société Géographique de Liège',
#  'uliege': 'Biotechnologie, Agronomie, Société et Environnement',
#  'humanistica': 'Humanistica Lovaniensia',
#  'cienciassociales': 'Revista Uruguaya de Ciencia Política',
#  'fenf': 'Revista Uruguaya de Enfermería',
#  'fder': 'Revista de la Facultad de Derecho',
#  'polarresearch': 'Polar Research',
#  'noda': 'På Spissen',
#  'bioingenioren': 'Bioingeniøren',
#  'inspiratidsskrift': 'Inspira',
#  'plutojournals': 'International Journal of Disability and Social Justice',
#  'acce': 'Australian Educational Computing',
#  'cmaj': 'CMAJ',
#  'alcesjournal': 'Alces',
#  'historicalstudiesineducation': 'Historical Studies in Education',
#  'ums': 'Journal of Islamic Economic Laws',
#  'uinsu': 'IJLRES (International Journal on Language Research and Education Studies)',
#  'undip': 'Jurnal Teknologi dan Sistem Komputer',
#  'upi': 'Indonesian Journal of Teaching in Science',
#  'uajy': 'Indonesian Journal of Information Systems',
#  'unila': 'Ius Poenale',
#  'berkalahayati': 'Journal of Biological Researches',
#  'walisongo': 'Daluang',
#  'itb': 'Communication in Biomathematical Sciences',
#  'its': 'JAREE (Journal on Advanced Research in Electrical Engineering)',
#  'urologi': 'Jurnal Urologi Indonesia',
#  'ahlimedia': 'Ilmu Kelautan',
#  'uii': 'Asian Journal of Islamic Management',
#  'radenintan': 'Revenue',
#  'stiemahardhika': 'Media Mahardhika: Media Komunikasi Ekonomi dan Manajemen',
#  'untagsmg': 'Jurnal Ilmiah Dunia Hukum',
#  'big': 'Geomatika',
#  'isi-dps': 'Mudra: Jurnal Seni Budaya',
#  'unsyiah': 'International Journal of Disaster Management',
#  'saripediatri': 'Sari Pediatri',
#  'asean-endocrinejournal': 'Journal of the ASEAN Federation of Endocrine Societies',
#  'chula': 'Journal of Health Research',
#  'spafajournal': 'SPAFA Journal',
#  'anglica-journal': 'Anglica. An International Journal of English Studies',
#  'iksiopan': 'Acta Asiatica Varsoviensia',
#  'advrehab': 'Advances in Rehabilitation',
#  'biotechnologia-journal': 'BioTechnologia',
#  'studialednickie': 'Studia Lednickie',
#  'uni-vt': 'Проглас',
#  'ceramics-silikaty': 'Ceramics-Silikáty',
#  'ihatuey': 'Pastos y Forrajes',
#  'cjascience': 'Cuban Journal of Agricultural Science',
#  'cubaenergia': 'Nucleus',
#  'insmet': 'Revista Cubana de Meteorología',
#  'unjc': 'Revista Cubana de Derecho',
#  'cigb': 'Biotecnología Aplicada',
#  'dlu': 'Tạp chí Khoa học Đại học Đà Lạt',
#  'archivesoftransport': 'Archives of Transport',
#  'sgh': 'Studia z Polityki Publicznej',
#  'forumoswiatowe': 'Forum Oświatowe',
#  'zfn': 'Zagadnienia Filozoficzne w Nauce',
#  'upjp2': 'The Person and the Challenges. The Journal of Theology, Education, Canon Law and Social Studies Inspired by Pope John Paul II',
#  'mjil': 'Московский журнал международного права',
#  'elpub': 'iPolytech Journal',
#  'sgu': 'Жанры речи',
#  'actamedicaportuguesa': 'Acta Médica Portuguesa',
#  'uminho': '2i Revista de Estudos de Identidade e Intermedialidade',
#  'mec': 'Portuguese Review of Mental Health Nursing',
#  'spnefro': 'Revista Portuguesa de Nefrologia e Hipertensão',
#  'ucp': 'Вестник Университета гражданской защиты МЧС Беларуси',
#  'interacoes-ismt': 'Interações',
#  'rppsicanalise': 'Revista Portuguesa de Psicanálise',
#  'cm-lisboa': 'Cadernos do Arquivo Municipal',
#  'esenfc': 'Revista de Enfermagem Referência',
#  'google': 'Közigazgatási és Infokommunikációs Jogi PhD Tanulmányok',
#  'apem-estudos': 'Ex Aequo: Revista da Associação Portuguesa de Estudos sobre as Mulheres',
#  'oraltradition': 'Oral Tradition',
#  'pjo': 'Pakistan Journal of Ophthalmology',
#  'culanth': 'Cultural Anthropology',
#  'tdl': 'The Journal of Forensic Science Education',
#  'escholarship': 'React/Review',
#  'mit': 'Harvard Data Science Review',
#  'scientificexploration': 'Journal of Scientific Exploration',
#  'apsnet': 'Phytobiomes Journal',
#  'ebhsoc': 'Essays in Economic and Business History',
#  'tidsskrift': 'Forskning i Pædagogers Profession og Uddannelse',
#  'ersjournals': 'ERJ Open Research',
#  'iucr': 'IUCrData',
#  'myukk': 'Sensors and Materials',
#  'isijint': 'ISIJ International',
#  'jspn': 'Nihon Shouni Jinzoubyou Gakkai zasshi',
#  'fujipress': 'International Journal of Automation Technology',
#  'js-phlebology': 'Jomyakugaku',
#  'jssmr': 'Journal of Smooth Muscle Research',
#  'reproduction': 'The Journal of Reproduction and Development',
#  'jeaweb': 'Journal of Epidemiology',
#  'erlacs': 'European Review of Latin American and Caribbean Studies',
#  'mab-online': 'MAB',
#  'sstp': 'Stem-, Spraak- en Taalpathologie',
#  'utrechtjournal': 'Utrecht Journal of International and European Law',
#  'jmuonline': 'Journal of Medical Ultrasound',
#  'european-journal-of-mineralogy': 'European Journal of Mineralogy',
#  'nordeuropaforum': 'NORDEUROPAforum - Zeitschrift für Kulturstudien',
#  'schweizerbart': 'Meteorologische Zeitschrift',
#  'journal-fuer-psychologie': 'Journal für Psychologie',
#  'jucs': 'Journal of Universal Computer Science',
#  'zfo-online': 'Zeitschrift für Ostmitteleuropa-Forschung',
#  'cehjournal': 'Community Eye Health Journal',
#  'wwt': 'Wildfowl',
#  'parksjournal': 'Parks',
#  'cardiffuniversitypress': 'Welsh Economic Review',
#  'ucl': 'Papers from the Institute of Archaeology',
#  'ijcm': 'Indian Journal of Community Medicine',
#  'indianjurol': 'Indian Journal of Urology',
#  'lungindia': 'Lung India',
#  'jisppd': 'Journal of Indian Society of Pedodontics and Preventive Dentistry',
#  'indianjpain': 'Indian Journal of Pain',
#  'endodontologyonweb': 'Endodontology',
#  'joacp': 'Journal of Anaesthesiology Clinical Pharmacology',
#  'ijdr': 'Indian Journal of Dental Research',
#  'jcytol': 'Journal of Cytology',
#  'jvas': 'Journal of Veterinary and Animal Sciences',
#  'thieme-connect': 'Indian Journal of Radiology and Imaging',
#  'extensioneducation': 'Journal of Extension Education',
#  'indianjnephrol': 'Indian Journal of Nephrology',
#  'ijmr': 'Indian Journal of Medical Research',
#  'jmp': 'Journal of Medicinal Plants',
#  'ijburns': 'Indian Journal of Burns',
#  'jmhhb': 'Journal of Mental Health and Human Behaviour',
#  'jiaps': 'Journal of Indian Association of Pediatric Surgeons',
#  'annals': 'Annals of Cardiac Anaesthesia',
#  'jmgims': 'Journal of Mahatma Gandhi Institute of Medical Sciences',
#  'indjsp': 'Indian Journal of Social Psychiatry',
#  'rpe': 'Radiation Protection and Environment',
#  'indjvascsurg': 'Indian Journal of Vascular and Endovascular Surgery',
#  'jisponline': 'Journal of Indian Society of Periodontology',
#  'jiaomr': 'Journal of Indian Academy of Oral Medicine and Radiology',
#  'annalsofian': 'Annals of Indian Academy of Neurology',
#  'environcj': 'Environment Conservation Journal',
#  'j-ips': 'The Journal of Indian Prosthodontic Society',
#  'conservationandsociety': 'Conservation & Society',
#  'ojhas': 'Online Journal of Health & Allied Sciences',
#  'neptjournal': 'Nature Environment and Pollution Technology',
#  'ijaai': 'Indian Journal of Allergy Asthma and Immunology',
#  'industrialpsychiatry': 'Industrial Psychiatry Journal',
#  'veterinaryworld': 'Veterinary World',
#  'jvbd': 'Journal of Vector Borne Diseases',
#  ...}

# %%
import json

scholarly_flags = {
    "red_scholarly": red_flags_dict,
    "red_scholarly_reverse": red_flags_reverse,
    "yellow_scholarly": yellow_flags_dict,
    "yellow_scholarly_reverse": yellow_flags_reverse,
    "green_scholarly": green_flags_dict,
    "green_scholarly_reverse": green_flags_reverse
}

with open("scholarly_flags.json", "w") as outfile:
    json.dump(scholarly_flags, outfile)
